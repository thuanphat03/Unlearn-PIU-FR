# %% [markdown]
# #### <b>Download the Original Datasets</b>
#
# * <b>CelebA-HQ Dataset</b>: A dataset consisting of 30,000 "human face" images.
#     * This dataset has approximately 3GB of data in size and is one of the most widely used face datasets worldwide.
# * <b>CelebA-HQ Identity Dataset</b>: A dataset that provides information about <b>who the individuals (subjects) are</b> for each facial image file.
# * <b>CelebA-HQ Attribute Dataset</b>: A dataset that provides attribute information for each facial image file.
#     * This attribute information includes <b>gender</b>, <b>smiling</b>, and <b>age</b>, which we will be used for a multi-label task.

# %%
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/Eb37jNPPA7hHl0fmktYqcV8B-qmPLx-ZKYQ1eFk4UPBV_A?download=1 -O CelebAMask-HQ.zip
# !wget https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVRoUY8_txRFv56-KWvZrksBDWbD6adkjBxwwRN7qAC6bg?download=1 -O CelebA-HQ-identity.txt
# !wget https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVrdIrPOkR1OlEWBVK8lE3AB9bFh741GnKBkNgPa8trNuA?download=1 -O CelebA-HQ-attribute.txt

# %%
# %%capture
# !rm -rf ./CelebAMask-HQ
# !unzip CelebAMask-HQ.zip

# %% [markdown]
# #### <b>Load Libraries</b>
#
# * Load various useful python libraries for the experiments.

# %%
import os
import time
import random
import glob
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, transforms, models
import torchvision.transforms.functional as TF
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn import linear_model, model_selection
from sklearn.utils import shuffle

# %%
def train(model, dataloader):
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Training]')
    model.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0
    log_step = 20

    for i, (imgs, labels) in enumerate(dataloader):
        imgs = imgs.cuda()
        labels = labels.cuda()

        outputs = model(imgs)
        optimizer.zero_grad()
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total += labels.size(0)
        running_loss += loss.item() * imgs.size(0)
        running_corrects += torch.sum(preds == labels)

        if (i + 1) % log_step == 0:
            current_loss = running_loss / total
            current_acc = running_corrects.double() / total
            print(f'[Batch: {i + 1}] running train loss: {current_loss:.4f}, running train accuracy: {current_acc:.4f}')

    epoch_loss = running_loss / total
    epoch_acc = running_corrects.double() / total
    print(f'train loss: {epoch_loss:.4f}, accuracy: {epoch_acc:.4f}')
    print("elapsed time:", time.time() - start_time)
    return epoch_loss, epoch_acc.item()


def test(model, dataloader):
    start_time = time.time()
    print('[Test]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0
    log_step=20

    for i, (imgs, labels) in enumerate(dataloader):
        imgs = imgs.cuda()
        labels = labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.size(0)
        running_loss += loss.item() * imgs.size(0)
        running_corrects += torch.sum(preds == labels)

        if (i == 0) or ((i + 1) % log_step == 0):
            current_loss = running_loss / total
            current_acc = running_corrects.double() / total
            print(f'[Batch: {i + 1}] running test loss: {current_loss:.4f}, running test accuracy: {current_acc:.4f}')

    epoch_loss = running_loss / total
    epoch_acc = running_corrects.double() / total
    print(f'test loss: {epoch_loss:.4f}, accuracy: {epoch_acc:.4f}')
    print("elapsed time:", time.time() - start_time)
    return epoch_loss, epoch_acc.item()

# %%
def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

def compute_losses(net, loader):
    criterion = nn.CrossEntropyLoss(reduction="none")
    all_losses = []
    
    for inputs, labels in loader:
        targets = labels
        inputs, targets = inputs.cuda(), targets.cuda()

        logits = net(inputs)
        losses = criterion(logits, targets).cpu().detach().numpy()
            
        #losses = criterion(logits, targets).numpy(force=True)
        for l in losses:
            all_losses.append(l)

    return np.array(all_losses)

def simple_mia(sample_loss, members, n_splits=10, random_state=0):
    unique_members = np.unique(members)
    if not np.all(unique_members == np.array([0, 1])):
        raise ValueError("members should only have 0 and 1s")

    attack_model = linear_model.LogisticRegression()
    cv = model_selection.StratifiedShuffleSplit(
        n_splits=n_splits, random_state=random_state
    )
    return model_selection.cross_val_score(
        attack_model, sample_loss, members, cv=cv, scoring="accuracy"
    )


def cal_mia(model, unseen_dataloader):

    set_seed(42)

    forget_losses = compute_losses(model, forget_dataloader_test)
    unseen_losses = compute_losses(model, unseen_dataloader)

    np.random.shuffle(forget_losses)
    forget_losses = forget_losses[: len(unseen_losses)]

    samples_mia = np.concatenate((unseen_losses, forget_losses)).reshape((-1, 1))
    labels_mia = [0] * len(unseen_losses) + [1] * len(forget_losses)

    mia_scores = simple_mia(samples_mia, labels_mia)
    forgetting_score = abs(0.5 - mia_scores.mean())

    return {'MIA': mia_scores.mean(), 'Forgeting Score': forgetting_score}


@torch.no_grad()
def evaluation(model, data_loader):
    model.eval()
    with torch.no_grad():
        running_loss = 0.
        running_corrects = 0

        for inputs, labels in data_loader:
            inputs = inputs.cuda()
            labels = labels.cuda()

            outputs = model(inputs)  # Use the passed model argument here
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Use data_loader's dataset length for normalization
        epoch_loss = running_loss / len(data_loader.dataset)
        epoch_loss = round(epoch_loss, 3)
        epoch_acc = running_corrects.item() / len(data_loader.dataset)

        return {'Loss': epoch_loss, 'Acc': epoch_acc}

# %% [markdown]
# #### <b>Load Identity Mapping</b>
# * Check which person each file name is associated with.
# * There are a total of 6,217 individuals (subjects) among the 30,000 files.

# %%
path = "./celeb_dataset/"

# %%
identities = {}

# (Image File Name, Subject Identity Information)
with open(path + 'CelebA-HQ-identity.txt') as f:
    lines = f.readlines()
    for line in lines:
        file_name, identity = line.strip().split()
        identities[file_name] = identity

print(f'There are {len(set(identities.values()))} identities.')
print(f'There are {len(identities.keys())} images.')
# Out:
# There are 6217 identities.
# There are 30000 images.

# %% [markdown]
# #### <b>Choose Single Label to Use</b>
# * "male": 21,
# * "smiling": 32,
# * "young": 40

# %%
label_map = {}

label_num = 21  # "male": 21, "smiling": 32, "young": 40

with open(path + 'CelebA-HQ-attribute.txt') as f:
    lines = f.readlines()
    for line in lines[2:]:
        splited = line.strip().split()
        file_name, label = splited[0], splited[label_num]
        label_map[file_name] = label

print(f'There are {len(set(label_map.values()))} classes.')
print(f'There are {len(label_map.keys())} images.')
# Out:
# There are 2 classes.
# There are 30000 images.

# %% [markdown]
# #### <b>Split the Dataset</b>
# * <b>Training dataset  $\mathcal{D}_{train}$</b>: 25,933 images.
# * <b>Test dataset $\mathcal{D}_{test}$</b>: 2,065 images.
# * <b>Unseen dataset $\mathcal{D}_{unseen}$</b>: 2,002 images.

# %%
source_root = path + 'CelebAMask-HQ/CelebA-HQ-img/'

train_index = 190
retrain_index = 1250
unseen_index = 4855

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity >= train_index and identity < unseen_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []
        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < train_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class ForgetDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity >= train_index and identity < retrain_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class RetrainDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index and identity >= retrain_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class UnseenDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None, train=False, test=False):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
         # Shuffle the list of image paths
        self.image_path_list = shuffle(self.image_path_list, random_state=42)
        
        self.transform = transform

        self.image_paths = []
        self.labels = []
        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0
            self.labels.append((label, identity))
            self.image_paths.append(image_path)
        
        if train:
            self.labels = self.labels[:int(len(self.labels) * 0.8)]
            self.image_paths = self.image_paths[:int(len(self.image_paths) * 0.8)]
        elif test:
            self.labels = self.labels[int(len(self.labels) * 0.8):]
            self.image_paths = self.image_paths[int(len(self.image_paths) * 0.8):]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
train_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.RandomHorizontalFlip(),
    transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.ToTensor()
])

unseen_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.ToTensor()
])

train_set = TrainDataset(transform=train_transform)
test_set = TestDataset(transform=test_transform)
forget_set_train = ForgetDataset(transform=train_transform)
forget_set_test = ForgetDataset(transform=test_transform)
retrain_set_train = RetrainDataset(transform=train_transform)
retrain_set_test = RetrainDataset(transform=test_transform)
unseen_set_train = UnseenDataset(transform=unseen_transform, train=True, test=False)
unseen_set_test = UnseenDataset(transform=unseen_transform, train=False, test=True)

# %%
print('Train dataset size:', len(train_set))
print('Test dataset size:', len(test_set))
print('Forget dataset size:', len(forget_set_train))
print('Retrain dataset size:', len(retrain_set_train))
print('Train Unseen dataset size:', len(unseen_set_train))
print('Test Unseen dataset size:', len(unseen_set_test))
# Out:
# Train dataset size: 25933
# Test dataset size: 2065
# Forget dataset size: 10183
# Retrain dataset size: 15750
# Train Unseen dataset size: 1601
# Test Unseen dataset size: 401

# %% [markdown]
# * In the NeurIPS Competition setting, when performing machine unlearning, training is done with 'retrain' and 'forget', so augmentation can be applied. However, it should never be applied during evaluation.

# %%
train_dataloader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True, pin_memory=True)
test_dataloader = torch.utils.data.DataLoader(test_set, batch_size=64, shuffle=False, pin_memory=True)
forget_dataloader_train = torch.utils.data.DataLoader(forget_set_train, batch_size=64, shuffle=False, pin_memory=True)
forget_dataloader_test = torch.utils.data.DataLoader(forget_set_test, batch_size=64, shuffle=False, pin_memory=True)
retrain_dataloader_train = torch.utils.data.DataLoader(retrain_set_train, batch_size=64, shuffle=True, pin_memory=True)
retrain_dataloader_test = torch.utils.data.DataLoader(retrain_set_test, batch_size=64, shuffle=False,pin_memory=True)
unseen_dataloader_train = torch.utils.data.DataLoader(unseen_set_train, batch_size=64, shuffle=False, pin_memory=True)
unseen_dataloader_test = torch.utils.data.DataLoader(unseen_set_test, batch_size=64, shuffle=False, pin_memory=True)

# %%
train_image_paths = TrainDataset().image_paths
test_image_paths = TestDataset().image_paths
forget_image_paths = ForgetDataset().image_paths
retrain_image_paths = RetrainDataset().image_paths
unseen_image_paths = UnseenDataset(train=True).image_paths

train_test_overlap = len(set(train_image_paths) & set(test_image_paths))
train_forget_overlap = len(set(train_image_paths) & set(forget_image_paths))
train_retrain_overlap = len(set(train_image_paths) & set(retrain_image_paths))
train_unseen_overlap = len(set(train_image_paths) & set(unseen_image_paths))
test_forget_overlap = len(set(test_image_paths) & set(forget_image_paths))
test_retrain_overlap = len(set(test_image_paths) & set(retrain_image_paths))
test_unseen_overlap = len(set(test_image_paths) & set(unseen_image_paths))
forget_retrain_overlap = len(set(forget_image_paths) & set(retrain_image_paths))
forget_unseen_overlap = len(set(forget_image_paths) & set(unseen_image_paths))
retrain_unseen_overlap = len(set(retrain_image_paths) & set(unseen_image_paths))

overlap_dict = {
    'train_test': train_test_overlap,
    'train_forget': train_forget_overlap,
    'train_retrain': train_retrain_overlap,
    'train_unseen': train_unseen_overlap,
    'test_forget': test_forget_overlap,
    'test_retrain': test_retrain_overlap,
    'test_unseen': test_unseen_overlap,
    'forget_retrain': forget_retrain_overlap,
    'forget_unseen': forget_unseen_overlap,
    'retrain_unseen': retrain_unseen_overlap
}
overlap_dict
# Out:
# {'train_test': 0,
#  'train_forget': 10183,
#  'train_retrain': 15750,
#  'train_unseen': 0,
#  'test_forget': 0,
#  'test_retrain': 0,
#  'test_unseen': 0,
#  'forget_retrain': 0,
#  'forget_unseen': 0,
#  'retrain_unseen': 0}

# %% [markdown]
# #### <b>Imgae Visualization</b>

# %%
if label_num == 21:
    label_convert = {0: "F", 1: "M"}
elif label_num == 32:
    label_convert = {0: "unsmiling", 1: "smiling"}
if label_num == 40:
    label_convert = {0: "old", 1: "young"}

# %%
def show_images(images, labels, nrow=6, save_path=None):
    n_images = len(images)
    nrows = n_images // nrow + (n_images % nrow > 0)

    fig, axs = plt.subplots(nrows, nrow, figsize=(14.5, 2.3 * nrows), frameon=False)
    axs = axs.flatten() if n_images > 1 else [axs]

    for idx, (img, label) in enumerate(zip(images, labels)):
        ax = axs[idx]
        img_np = img.numpy().transpose((1, 2, 0))
        ax.imshow(img_np)
        ax.axis('off')

        ax.text(5, 5, label, color='white', fontsize=13,  ha='left', va='top',
                bbox=dict(facecolor='black', alpha=0.5, boxstyle='round,pad=0.1'))

    plt.tight_layout(pad=0)

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)

    plt.show()

iterator = iter(test_dataloader)
imgs, labels = next(iterator)

label_strs = [label_convert[label.item()] for label in labels[0:12]]

show_images(imgs[0:12], label_strs, nrow=6)

# %% [markdown]
# # Train original model

# %%
learning_rate = 0.01
log_step = 30

model = models.resnet18(pretrained=False)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
history = []
accuracy = []
num_original_epochs = 10
for epoch in range(num_original_epochs):
    train_loss, train_acc = train(model, train_dataloader)
    test_loss, test_acc = test(model, test_dataloader)
    history.append((train_loss, test_loss))
    accuracy.append((train_acc, test_acc))

torch.save(model.state_dict(), f'last_checkpoint_epoch_{num_original_epochs}_sex.pth')
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.7476, running train accuracy: 0.5492
# [Batch: 40] running train loss: 0.7444, running train accuracy: 0.5824
# [Batch: 60] running train loss: 0.7072, running train accuracy: 0.6208
# [Batch: 80] running train loss: 0.6382, running train accuracy: 0.6707
# [Batch: 100] running train loss: 0.5808, running train accuracy: 0.7041
# [Batch: 120] running train loss: 0.5354, running train accuracy: 0.7312
# [Batch: 140] running train loss: 0.5003, running train accuracy: 0.7515
# [Batch: 160] running train loss: 0.4644, running train accuracy: 0.7706
# [Batch: 180] running train loss: 0.4394, running train accuracy: 0.7854
# [Batch: 200] running train loss: 0.4164, running train accuracy: 0.7984
# [Batch: 220] running train loss: 0.4006, running train accuracy: 0.8081
# [Batch: 240] running train loss: 0.3862, running train accuracy: 0.8161
# [Batch: 260] running train loss: 0.3699, running train accuracy: 0.8251
# [Batch: 280] running train loss: 0.3564, running train accuracy: 0.8324
# [Batch: 300] running train loss: 0.3449, running train accuracy: 0.8390
# [Batch: 320] running train loss: 0.3333, running train accuracy: 0.8455
# [Batch: 340] running train loss: 0.3233, running train accuracy: 0.8507
# [Batch: 360] running train loss: 0.3137, running train accuracy: 0.8554
# [Batch: 380] running train loss: 0.3066, running train accuracy: 0.8593
# [Batch: 400] running train loss: 0.2996, running train accuracy: 0.8631
# train loss: 0.2981, accuracy: 0.8638
# elapsed time: 564.9996645450592
# [Test]
# [Batch: 1] running test loss: 0.1807, running test accuracy: 0.8750
# [Batch: 20] running test loss: 0.1659, running test accuracy: 0.9258
# test loss: 0.1499, accuracy: 0.9317
# elapsed time: 40.587775468826294
# [Epoch: 2 - Training]
# [Batch: 20] running train loss: 0.2029, running train accuracy: 0.9250
# [Batch: 40] running train loss: 0.1793, running train accuracy: 0.9289
# [Batch: 60] running train loss: 0.1668, running train accuracy: 0.9354
# [Batch: 80] running train loss: 0.1664, running train accuracy: 0.9365
# [Batch: 100] running train loss: 0.1596, running train accuracy: 0.9395
# [Batch: 120] running train loss: 0.1561, running train accuracy: 0.9398
# [Batch: 140] running train loss: 0.1564, running train accuracy: 0.9402
# [Batch: 160] running train loss: 0.1519, running train accuracy: 0.9417
# [Batch: 180] running train loss: 0.1496, running train accuracy: 0.9427
# [Batch: 200] running train loss: 0.1511, running train accuracy: 0.9427
# [Batch: 220] running train loss: 0.1494, running train accuracy: 0.9430
# [Batch: 240] running train loss: 0.1484, running train accuracy: 0.9428
# [Batch: 260] running train loss: 0.1467, running train accuracy: 0.9436
# [Batch: 280] running train loss: 0.1451, running train accuracy: 0.9444
# [Batch: 300] running train loss: 0.1426, running train accuracy: 0.9454
# [Batch: 320] running train loss: 0.1411, running train accuracy: 0.9458
# [Batch: 340] running train loss: 0.1382, running train accuracy: 0.9468
# [Batch: 360] running train loss: 0.1372, running train accuracy: 0.9470
# [Batch: 380] running train loss: 0.1369, running train accuracy: 0.9468
# [Batch: 400] running train loss: 0.1351, running train accuracy: 0.9475
# train loss: 0.1344, accuracy: 0.9477
# elapsed time: 549.7823176383972
# [Test]
# [Batch: 1] running test loss: 0.1518, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.1217, running test accuracy: 0.9516
# test loss: 0.1300, accuracy: 0.9462
# elapsed time: 40.53649687767029
# [Epoch: 3 - Training]
# [Batch: 20] running train loss: 0.1189, running train accuracy: 0.9555
# [Batch: 40] running train loss: 0.1242, running train accuracy: 0.9520
# [Batch: 60] running train loss: 0.1214, running train accuracy: 0.9544
# [Batch: 80] running train loss: 0.1168, running train accuracy: 0.9561
# [Batch: 100] running train loss: 0.1125, running train accuracy: 0.9572
# [Batch: 120] running train loss: 0.1120, running train accuracy: 0.9576
# [Batch: 140] running train loss: 0.1126, running train accuracy: 0.9576
# [Batch: 160] running train loss: 0.1099, running train accuracy: 0.9582
# [Batch: 180] running train loss: 0.1093, running train accuracy: 0.9585
# [Batch: 200] running train loss: 0.1100, running train accuracy: 0.9583
# [Batch: 220] running train loss: 0.1102, running train accuracy: 0.9575
# [Batch: 240] running train loss: 0.1095, running train accuracy: 0.9579
# [Batch: 260] running train loss: 0.1091, running train accuracy: 0.9582
# [Batch: 280] running train loss: 0.1073, running train accuracy: 0.9588
# [Batch: 300] running train loss: 0.1065, running train accuracy: 0.9593
# [Batch: 320] running train loss: 0.1057, running train accuracy: 0.9595
# [Batch: 340] running train loss: 0.1049, running train accuracy: 0.9600
# [Batch: 360] running train loss: 0.1056, running train accuracy: 0.9599
# [Batch: 380] running train loss: 0.1057, running train accuracy: 0.9600
# [Batch: 400] running train loss: 0.1045, running train accuracy: 0.9606
# train loss: 0.1040, accuracy: 0.9607
# elapsed time: 544.6215517520905
# [Test]
# [Batch: 1] running test loss: 0.1161, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.0772, running test accuracy: 0.9688
# test loss: 0.0807, accuracy: 0.9685
# elapsed time: 40.82250690460205
# [Epoch: 4 - Training]
# [Batch: 20] running train loss: 0.0839, running train accuracy: 0.9680
# [Batch: 40] running train loss: 0.0935, running train accuracy: 0.9652
# [Batch: 60] running train loss: 0.0875, running train accuracy: 0.9669
# [Batch: 80] running train loss: 0.0867, running train accuracy: 0.9678
# [Batch: 100] running train loss: 0.0847, running train accuracy: 0.9684
# [Batch: 120] running train loss: 0.0827, running train accuracy: 0.9699
# [Batch: 140] running train loss: 0.0842, running train accuracy: 0.9699
# [Batch: 160] running train loss: 0.0845, running train accuracy: 0.9698
# [Batch: 180] running train loss: 0.0838, running train accuracy: 0.9702
# [Batch: 200] running train loss: 0.0842, running train accuracy: 0.9696
# [Batch: 220] running train loss: 0.0865, running train accuracy: 0.9680
# [Batch: 240] running train loss: 0.0941, running train accuracy: 0.9654
# [Batch: 260] running train loss: 0.0938, running train accuracy: 0.9657
# [Batch: 280] running train loss: 0.0937, running train accuracy: 0.9660
# [Batch: 300] running train loss: 0.0932, running train accuracy: 0.9658
# [Batch: 320] running train loss: 0.0924, running train accuracy: 0.9661
# [Batch: 340] running train loss: 0.0919, running train accuracy: 0.9663
# [Batch: 360] running train loss: 0.0911, running train accuracy: 0.9665
# [Batch: 380] running train loss: 0.0916, running train accuracy: 0.9664
# [Batch: 400] running train loss: 0.0900, running train accuracy: 0.9670
# train loss: 0.0898, accuracy: 0.9670
# elapsed time: 543.3206698894501
# [Test]
# [Batch: 1] running test loss: 0.1056, running test accuracy: 0.9844
# [Batch: 20] running test loss: 0.0650, running test accuracy: 0.9773
# test loss: 0.0651, accuracy: 0.9763
# elapsed time: 40.40339946746826
# [Epoch: 5 - Training]
# [Batch: 20] running train loss: 0.0875, running train accuracy: 0.9688
# [Batch: 40] running train loss: 0.0766, running train accuracy: 0.9723
# [Batch: 60] running train loss: 0.0792, running train accuracy: 0.9690
# [Batch: 80] running train loss: 0.0785, running train accuracy: 0.9693
# [Batch: 100] running train loss: 0.0776, running train accuracy: 0.9698
# [Batch: 120] running train loss: 0.0766, running train accuracy: 0.9698
# [Batch: 140] running train loss: 0.0747, running train accuracy: 0.9709
# [Batch: 160] running train loss: 0.0747, running train accuracy: 0.9709
# [Batch: 180] running train loss: 0.0736, running train accuracy: 0.9709
# [Batch: 200] running train loss: 0.0737, running train accuracy: 0.9709
# [Batch: 220] running train loss: 0.0743, running train accuracy: 0.9707
# [Batch: 240] running train loss: 0.0748, running train accuracy: 0.9705
# [Batch: 260] running train loss: 0.0745, running train accuracy: 0.9709
# [Batch: 280] running train loss: 0.0755, running train accuracy: 0.9704
# [Batch: 300] running train loss: 0.0757, running train accuracy: 0.9703
# [Batch: 320] running train loss: 0.0762, running train accuracy: 0.9699
# [Batch: 340] running train loss: 0.0763, running train accuracy: 0.9701
# [Batch: 360] running train loss: 0.0763, running train accuracy: 0.9702
# [Batch: 380] running train loss: 0.0759, running train accuracy: 0.9702
# [Batch: 400] running train loss: 0.0762, running train accuracy: 0.9704
# train loss: 0.0759, accuracy: 0.9705
# elapsed time: 544.1352953910828
# [Test]
# [Batch: 1] running test loss: 0.0866, running test accuracy: 0.9531
# [Batch: 20] running test loss: 0.0626, running test accuracy: 0.9750
# test loss: 0.0596, accuracy: 0.9763
# elapsed time: 41.1777925491333
# [Epoch: 6 - Training]
# [Batch: 20] running train loss: 0.0570, running train accuracy: 0.9781
# [Batch: 40] running train loss: 0.0596, running train accuracy: 0.9785
# [Batch: 60] running train loss: 0.0567, running train accuracy: 0.9797
# [Batch: 80] running train loss: 0.0570, running train accuracy: 0.9789
# [Batch: 100] running train loss: 0.0608, running train accuracy: 0.9767
# [Batch: 120] running train loss: 0.0626, running train accuracy: 0.9759
# [Batch: 140] running train loss: 0.0626, running train accuracy: 0.9760
# [Batch: 160] running train loss: 0.0700, running train accuracy: 0.9728
# [Batch: 180] running train loss: 0.0710, running train accuracy: 0.9722
# [Batch: 200] running train loss: 0.0714, running train accuracy: 0.9725
# [Batch: 220] running train loss: 0.0709, running train accuracy: 0.9729
# [Batch: 240] running train loss: 0.0712, running train accuracy: 0.9729
# [Batch: 260] running train loss: 0.0706, running train accuracy: 0.9729
# [Batch: 280] running train loss: 0.0708, running train accuracy: 0.9728
# [Batch: 300] running train loss: 0.0713, running train accuracy: 0.9728
# [Batch: 320] running train loss: 0.0705, running train accuracy: 0.9731
# [Batch: 340] running train loss: 0.0702, running train accuracy: 0.9734
# [Batch: 360] running train loss: 0.0700, running train accuracy: 0.9735
# [Batch: 380] running train loss: 0.0703, running train accuracy: 0.9734
# [Batch: 400] running train loss: 0.0705, running train accuracy: 0.9732
# train loss: 0.0706, accuracy: 0.9732
# elapsed time: 599.8372123241425
# [Test]
# [Batch: 1] running test loss: 0.0900, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0498, running test accuracy: 0.9844
# test loss: 0.0497, accuracy: 0.9816
# elapsed time: 55.30058479309082
# [Epoch: 7 - Training]
# [Batch: 20] running train loss: 0.0642, running train accuracy: 0.9734
# [Batch: 40] running train loss: 0.0613, running train accuracy: 0.9750
# [Batch: 60] running train loss: 0.0576, running train accuracy: 0.9771
# [Batch: 80] running train loss: 0.0588, running train accuracy: 0.9771
# [Batch: 100] running train loss: 0.0617, running train accuracy: 0.9766
# [Batch: 120] running train loss: 0.0620, running train accuracy: 0.9766
# [Batch: 140] running train loss: 0.0623, running train accuracy: 0.9767
# [Batch: 160] running train loss: 0.0639, running train accuracy: 0.9766
# [Batch: 180] running train loss: 0.0643, running train accuracy: 0.9761
# [Batch: 200] running train loss: 0.0640, running train accuracy: 0.9763
# [Batch: 220] running train loss: 0.0630, running train accuracy: 0.9763
# [Batch: 240] running train loss: 0.0622, running train accuracy: 0.9766
# [Batch: 260] running train loss: 0.0641, running train accuracy: 0.9761
# [Batch: 280] running train loss: 0.0662, running train accuracy: 0.9752
# [Batch: 300] running train loss: 0.0647, running train accuracy: 0.9758
# [Batch: 320] running train loss: 0.0640, running train accuracy: 0.9758
# [Batch: 340] running train loss: 0.0648, running train accuracy: 0.9758
# [Batch: 360] running train loss: 0.0649, running train accuracy: 0.9757
# [Batch: 380] running train loss: 0.0653, running train accuracy: 0.9756
# [Batch: 400] running train loss: 0.0661, running train accuracy: 0.9753
# train loss: 0.0661, accuracy: 0.9754
# elapsed time: 668.1831803321838
# [Test]
# [Batch: 1] running test loss: 0.0615, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0633, running test accuracy: 0.9758
# test loss: 0.0659, accuracy: 0.9743
# elapsed time: 41.05755686759949
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.0461, running train accuracy: 0.9828
# [Batch: 40] running train loss: 0.0459, running train accuracy: 0.9836
# [Batch: 60] running train loss: 0.0450, running train accuracy: 0.9839
# [Batch: 80] running train loss: 0.0487, running train accuracy: 0.9830
# [Batch: 100] running train loss: 0.0510, running train accuracy: 0.9817
# [Batch: 120] running train loss: 0.0523, running train accuracy: 0.9811
# [Batch: 140] running train loss: 0.0526, running train accuracy: 0.9811
# [Batch: 160] running train loss: 0.0535, running train accuracy: 0.9809
# [Batch: 180] running train loss: 0.0540, running train accuracy: 0.9806
# [Batch: 200] running train loss: 0.0540, running train accuracy: 0.9808
# [Batch: 220] running train loss: 0.0547, running train accuracy: 0.9803
# [Batch: 240] running train loss: 0.0565, running train accuracy: 0.9794
# [Batch: 260] running train loss: 0.0575, running train accuracy: 0.9790
# [Batch: 280] running train loss: 0.0575, running train accuracy: 0.9789
# [Batch: 300] running train loss: 0.0567, running train accuracy: 0.9789
# [Batch: 320] running train loss: 0.0572, running train accuracy: 0.9788
# [Batch: 340] running train loss: 0.0585, running train accuracy: 0.9784
# [Batch: 360] running train loss: 0.0589, running train accuracy: 0.9782
# [Batch: 380] running train loss: 0.0590, running train accuracy: 0.9781
# [Batch: 400] running train loss: 0.0596, running train accuracy: 0.9780
# train loss: 0.0596, accuracy: 0.9780
# elapsed time: 560.9028794765472
# [Test]
# [Batch: 1] running test loss: 0.0596, running test accuracy: 0.9844
# [Batch: 20] running test loss: 0.0440, running test accuracy: 0.9844
# test loss: 0.0476, accuracy: 0.9816
# elapsed time: 41.17434215545654
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.0532, running train accuracy: 0.9773
# [Batch: 40] running train loss: 0.0571, running train accuracy: 0.9781
# [Batch: 60] running train loss: 0.0540, running train accuracy: 0.9792
# [Batch: 80] running train loss: 0.0535, running train accuracy: 0.9795
# [Batch: 100] running train loss: 0.0508, running train accuracy: 0.9809
# [Batch: 120] running train loss: 0.0541, running train accuracy: 0.9798
# [Batch: 140] running train loss: 0.0526, running train accuracy: 0.9802
# [Batch: 160] running train loss: 0.0524, running train accuracy: 0.9803
# [Batch: 180] running train loss: 0.0517, running train accuracy: 0.9806
# [Batch: 200] running train loss: 0.0534, running train accuracy: 0.9799
# [Batch: 220] running train loss: 0.0540, running train accuracy: 0.9800
# [Batch: 240] running train loss: 0.0540, running train accuracy: 0.9800
# [Batch: 260] running train loss: 0.0538, running train accuracy: 0.9803
# [Batch: 280] running train loss: 0.0541, running train accuracy: 0.9804
# [Batch: 300] running train loss: 0.0544, running train accuracy: 0.9801
# [Batch: 320] running train loss: 0.0538, running train accuracy: 0.9801
# [Batch: 340] running train loss: 0.0538, running train accuracy: 0.9802
# [Batch: 360] running train loss: 0.0531, running train accuracy: 0.9805
# [Batch: 380] running train loss: 0.0542, running train accuracy: 0.9801
# [Batch: 400] running train loss: 0.0538, running train accuracy: 0.9804
# train loss: 0.0536, accuracy: 0.9804
# elapsed time: 553.079051733017
# [Test]
# [Batch: 1] running test loss: 0.0915, running test accuracy: 0.9531
# [Batch: 20] running test loss: 0.0624, running test accuracy: 0.9742
# test loss: 0.0645, accuracy: 0.9724
# elapsed time: 41.05712127685547
# [Epoch: 10 - Training]
# [Batch: 20] running train loss: 0.0377, running train accuracy: 0.9844
# [Batch: 40] running train loss: 0.0438, running train accuracy: 0.9828
# [Batch: 60] running train loss: 0.0469, running train accuracy: 0.9818
# [Batch: 80] running train loss: 0.0468, running train accuracy: 0.9822
# [Batch: 100] running train loss: 0.0443, running train accuracy: 0.9830
# [Batch: 120] running train loss: 0.0453, running train accuracy: 0.9831
# [Batch: 140] running train loss: 0.0463, running train accuracy: 0.9830
# [Batch: 160] running train loss: 0.0453, running train accuracy: 0.9833
# [Batch: 180] running train loss: 0.0466, running train accuracy: 0.9827
# [Batch: 200] running train loss: 0.0472, running train accuracy: 0.9823
# [Batch: 220] running train loss: 0.0464, running train accuracy: 0.9830
# [Batch: 240] running train loss: 0.0455, running train accuracy: 0.9833
# [Batch: 260] running train loss: 0.0459, running train accuracy: 0.9831
# [Batch: 280] running train loss: 0.0452, running train accuracy: 0.9832
# [Batch: 300] running train loss: 0.0466, running train accuracy: 0.9827
# [Batch: 320] running train loss: 0.0475, running train accuracy: 0.9822
# [Batch: 340] running train loss: 0.0491, running train accuracy: 0.9815
# [Batch: 360] running train loss: 0.0491, running train accuracy: 0.9814
# [Batch: 380] running train loss: 0.0490, running train accuracy: 0.9815
# [Batch: 400] running train loss: 0.0496, running train accuracy: 0.9815
# train loss: 0.0500, accuracy: 0.9813
# elapsed time: 544.9425282478333
# [Test]
# [Batch: 1] running test loss: 0.0725, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0490, running test accuracy: 0.9859
# test loss: 0.0519, accuracy: 0.9816
# elapsed time: 40.8772349357605

# %%
import matplotlib.pyplot as plt

train_losses, test_losses = zip(*history)
train_accuracies, test_accuracies = zip(*accuracy)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Test Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Forgetting Functions

# %%
random.seed(42)

# %% [markdown]
# # Stage 1: Forgetting via PIU-FR

# %%
# original_save_path = f'last_checkpoint_epoch_{num_original_epochs}_gender.pth' # If you trian the original model from scratch.
original_save_path = f'last_checkpoint_epoch_10_sex.pth'  # downloaded model
original_model = models.resnet18(pretrained=False)
num_features = original_model.fc.in_features
original_model.fc = nn.Linear(num_features, 2)
original_model = original_model.cuda()
original_model.load_state_dict(torch.load(original_save_path))
criterion = nn.CrossEntropyLoss()

# %%
# Performance
log_step = 30
test_acc = evaluation(original_model, test_dataloader)
unseen_acc = evaluation(original_model, unseen_dataloader_test)
mia = cal_mia(original_model.cuda(), unseen_dataloader_test)
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.052, 'Acc': 0.9815980629539952}
# Unseen Acc: {'Loss': 0.064, 'Acc': 0.9775561097256857}
# MIA: {'MIA': 0.5234567901234567, 'Forgeting Score': 0.023456790123456694}
# Final Score: 0.9673422413535409

# %%
# original_save_path = f'last_checkpoint_epoch_{num_original_epochs}_gender.pth' # If you trian the original model from scratch.
original_save_path = f'last_checkpoint_epoch_10_sex.pth'  # downloaded model
forgot_model = models.resnet18(pretrained=False)
num_features = forgot_model.fc.in_features
forgot_model.fc = nn.Linear(num_features, 2)
forgot_model = forgot_model.cuda()
forgot_model.load_state_dict(torch.load(original_save_path))
criterion = nn.CrossEntropyLoss()

# %%
class DistillKL(nn.Module):
    def __init__(self, T):
        super(DistillKL, self).__init__()
        self.T = T

    def forward(self, y_s, y_t):
        p_s = F.log_softmax(y_s/self.T, dim=1)
        p_t = F.softmax(y_t/self.T, dim=1)
        loss = F.kl_div(p_s, p_t, size_average=False) * (self.T**2) / y_s.shape[0]
        return loss

# %%
class NewUnseenDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None, unseen_set_train=None, forget_dataloader=None):
        self.transform = transform

        self.image_paths = []
        self.labels = []
        self.unseen_set_train = unseen_set_train
        self.image_path_list = self.unseen_set_train.image_paths
        self.forget_dataloader = forget_dataloader

        # Create a dict consist of image_path follow gender, smilling and young
        dict_labels_path = {}
        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0

            # Use the (gender, smiling, young) tuple as the dictionary key
            key = label

            # Check if the key exists in the dictionary
            if key in dict_labels_path:
                dict_labels_path[key].append(image_path)
            else:
                dict_labels_path[key] = [image_path]

        # Create a new image_list
        new_image_list = []

        for i, (inputs_forget, label) in enumerate(self.forget_dataloader):
            # Convert labels to the same format as the outputs (float).
            labels_forget = label.cuda()
            
            for label in labels_forget:
                # Convert tensor label to tuple for dictionary key
                key = int(label)
                
                # Ensure the key exists in the dictionary
                if key in dict_labels_path and dict_labels_path[key]:
                    # Randomly select a sample from the list associated with this key
                    chosen_sample = random.choice(dict_labels_path[key])
                    new_image_list.append(chosen_sample)
                else:
                    # Handle the case where the key does not exist or has no associated samples
                    print(f"No samples found for key {key}")

        self.image_path_list = new_image_list

        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0
         
            self.labels.append((label, identity))
            self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class PIU_FR:
    def __init__(self, original_model, forgot_model, unseen_set_train, forget_dataloader):
        self.original_model = original_model
        self.forgot_model = forgot_model
        self.forget_dataloader = forget_dataloader
        self.unseen_set_train = unseen_set_train
        self.criterion_div = DistillKL(4.0)
        self.optimizer = optim.SGD(self.forgot_model.parameters(), lr=0.001)
        self.criterion = torch.nn.CrossEntropyLoss()

    def train_epoch(self):
        set_seed(42)
        self.forgot_model.train()
        self.original_model.eval()

        # Function to compute accuracy.
        def compute_accuracy(outputs, labels):
            _, predicted = outputs.max(1)
            total = labels.size(0)
            correct = predicted.eq(labels).sum().item()
            return 100 * correct / total

        total_loss_div, total_accuracy_forget = 0, 0
        
        # Process new unseen_dataloader
        new_unseen_dataset = NewUnseenDataset(unseen_transform, unseen_set_train=self.unseen_set_train, forget_dataloader=self.forget_dataloader)
        new_unseen_dataloader = DataLoader(new_unseen_dataset, batch_size=64, shuffle=False)
        
        # Training with unseen data.
        flag = 1

        for (inputs_unseen, labels_unseen), (inputs_forget, labels_forget) in zip(new_unseen_dataloader, self.forget_dataloader):
            inputs_unseen, labels_unseen = inputs_unseen.cuda(), labels_unseen.cuda()
            inputs_forget, labels_forget = inputs_forget.cuda(), labels_forget.cuda()

            outputs_forget = self.forgot_model(inputs_forget)

            with torch.no_grad():
                outputs_unseen = self.original_model(inputs_unseen)

            # Loss computation
            loss_div = flag * self.criterion_div(outputs_forget, outputs_unseen)

            # Update total loss and accuracy for unseen data.
            total_loss_div += loss_div.item()
            total_accuracy_forget += compute_accuracy(outputs_forget, labels_forget)

            # Backward pass
            self.optimizer.zero_grad()
            loss_div.backward()
            self.optimizer.step()
            
            if flag == 1:
                flag = -1
            else:
                flag = 1

        # Print average loss and accuracy for the entire epoch
        avg_loss_div = total_loss_div / len(self.forget_dataloader)
        avg_accuracy_forget = total_accuracy_forget / len(self.forget_dataloader)

        mia = cal_mia(self.forgot_model.cuda(), unseen_dataloader_train)

        print(f'Epoch unseen: Avg Loss: {avg_loss_div:.4f}, Avg Accuracy: {avg_accuracy_forget:.2f}, Forgeting Score: {mia["Forgeting Score"]}')

# %%
set_seed(42)

# Initialize and train
forgetting_trainer = PIU_FR(original_model, forgot_model, unseen_set_train, forget_dataloader_train)

num_epochs = 1
for epoch in range(num_epochs):
    forgetting_trainer.train_epoch()
    print(f"Epoch {epoch+1} completed.")
# Out:
# Epoch unseen: Avg Loss: 0.0764, Avg Accuracy: 97.61, Forgeting Score: 0.0006230529595016021
# Epoch 1 completed.

# %%
# Performance
log_step = 30
test_acc = evaluation(forgot_model, test_dataloader)
unseen_acc = evaluation(forgot_model, unseen_dataloader_test)
mia = cal_mia(forgot_model.cuda(), unseen_dataloader_test)
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.049, 'Acc': 0.9840193704600484}
# Unseen Acc: {'Loss': 0.071, 'Acc': 0.9800498753117207}
# MIA: {'MIA': 0.5259259259259259, 'Forgeting Score': 0.025925925925925908}
# Final Score: 0.9660837593040983

# %% [markdown]
# # Stage 2: Improve accuracy (Optional)

# %%
num_epochs = 1
learning_rate = 0.01
log_step = 30

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(forgot_model.parameters(), lr=learning_rate, momentum=0.9)

for epoch in range(num_epochs):
   train_loss, train_acc = train(forgot_model, retrain_dataloader_train)
   test_loss, test_acc = test(forgot_model, test_dataloader)

# %%
#Performance
log_step = 30
test_acc = evaluation(forgot_model, test_dataloader)
unseen_acc = evaluation(forgot_model, unseen_dataloader_test)
mia = cal_mia(forgot_model.cuda(), unseen_dataloader_test)
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')

# %% [markdown]
# # Retrained Model

# %%
learning_rate = 0.01
log_step = 30

retrained_model = models.resnet18(pretrained=False)
num_features = retrained_model.fc.in_features
retrained_model.fc = nn.Linear(num_features, 2)
retrained_model = retrained_model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(retrained_model.parameters(), lr=learning_rate, momentum=0.9)

# %%
learning_rate = 0.01
best_test_acc = 0
best_epoch = 0

history = []
accuracy = []
num_original_epochs = 10
for epoch in range(num_original_epochs):
    train_loss, train_acc = train(retrained_model, retrain_dataloader_train)
    test_loss, test_acc = test(retrained_model, test_dataloader)
    history.append((train_loss, test_loss))
    accuracy.append((train_acc, test_acc))
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.7362, running train accuracy: 0.5398
# [Batch: 40] running train loss: 0.7160, running train accuracy: 0.5695
# [Batch: 60] running train loss: 0.6529, running train accuracy: 0.6292
# [Batch: 80] running train loss: 0.5886, running train accuracy: 0.6773
# [Batch: 100] running train loss: 0.5438, running train accuracy: 0.7105
# [Batch: 120] running train loss: 0.5040, running train accuracy: 0.7370
# [Batch: 140] running train loss: 0.4700, running train accuracy: 0.7567
# [Batch: 160] running train loss: 0.4437, running train accuracy: 0.7724
# [Batch: 180] running train loss: 0.4210, running train accuracy: 0.7874
# [Batch: 200] running train loss: 0.4040, running train accuracy: 0.7984
# [Batch: 220] running train loss: 0.3855, running train accuracy: 0.8097
# [Batch: 240] running train loss: 0.3692, running train accuracy: 0.8187
# train loss: 0.3655, accuracy: 0.8212
# elapsed time: 484.6615924835205
# [Test]
# [Batch: 1] running test loss: 0.0930, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0989, running test accuracy: 0.9617
# test loss: 0.0993, accuracy: 0.9617
# elapsed time: 57.2175190448761
# [Epoch: 2 - Training]
# [Batch: 20] running train loss: 0.2127, running train accuracy: 0.9148
# [Batch: 40] running train loss: 0.2002, running train accuracy: 0.9207
# [Batch: 60] running train loss: 0.2026, running train accuracy: 0.9203
# [Batch: 80] running train loss: 0.1989, running train accuracy: 0.9217
# [Batch: 100] running train loss: 0.1938, running train accuracy: 0.9244
# [Batch: 120] running train loss: 0.1869, running train accuracy: 0.9262
# [Batch: 140] running train loss: 0.1868, running train accuracy: 0.9263
# [Batch: 160] running train loss: 0.1828, running train accuracy: 0.9280
# [Batch: 180] running train loss: 0.1821, running train accuracy: 0.9289
# [Batch: 200] running train loss: 0.1798, running train accuracy: 0.9291
# [Batch: 220] running train loss: 0.1780, running train accuracy: 0.9296
# [Batch: 240] running train loss: 0.1763, running train accuracy: 0.9307
# train loss: 0.1754, accuracy: 0.9310
# elapsed time: 363.6563620567322
# [Test]
# [Batch: 1] running test loss: 0.1758, running test accuracy: 0.9375
# [Batch: 20] running test loss: 0.1687, running test accuracy: 0.9383
# test loss: 0.1823, accuracy: 0.9317
# elapsed time: 44.38466691970825
# [Epoch: 3 - Training]
# [Batch: 20] running train loss: 0.1308, running train accuracy: 0.9484
# [Batch: 40] running train loss: 0.1375, running train accuracy: 0.9469
# [Batch: 60] running train loss: 0.1377, running train accuracy: 0.9445
# [Batch: 80] running train loss: 0.1362, running train accuracy: 0.9457
# [Batch: 100] running train loss: 0.1358, running train accuracy: 0.9450
# [Batch: 120] running train loss: 0.1354, running train accuracy: 0.9457
# [Batch: 140] running train loss: 0.1346, running train accuracy: 0.9458
# [Batch: 160] running train loss: 0.1346, running train accuracy: 0.9468
# [Batch: 180] running train loss: 0.1380, running train accuracy: 0.9451
# [Batch: 200] running train loss: 0.1373, running train accuracy: 0.9455
# [Batch: 220] running train loss: 0.1345, running train accuracy: 0.9467
# [Batch: 240] running train loss: 0.1350, running train accuracy: 0.9467
# train loss: 0.1347, accuracy: 0.9469
# elapsed time: 386.6631381511688
# [Test]
# [Batch: 1] running test loss: 0.1471, running test accuracy: 0.9531
# [Batch: 20] running test loss: 0.0957, running test accuracy: 0.9664
# test loss: 0.1020, accuracy: 0.9608
# elapsed time: 46.23064303398132
# [Epoch: 4 - Training]
# [Batch: 20] running train loss: 0.1279, running train accuracy: 0.9500
# [Batch: 40] running train loss: 0.1112, running train accuracy: 0.9551
# [Batch: 60] running train loss: 0.1207, running train accuracy: 0.9529
# [Batch: 80] running train loss: 0.1310, running train accuracy: 0.9504
# [Batch: 100] running train loss: 0.1319, running train accuracy: 0.9497
# [Batch: 120] running train loss: 0.1259, running train accuracy: 0.9521
# [Batch: 140] running train loss: 0.1232, running train accuracy: 0.9529
# [Batch: 160] running train loss: 0.1214, running train accuracy: 0.9542
# [Batch: 180] running train loss: 0.1209, running train accuracy: 0.9548
# [Batch: 200] running train loss: 0.1208, running train accuracy: 0.9545
# [Batch: 220] running train loss: 0.1204, running train accuracy: 0.9548
# [Batch: 240] running train loss: 0.1192, running train accuracy: 0.9553
# train loss: 0.1192, accuracy: 0.9555
# elapsed time: 357.8017518520355
# [Test]
# [Batch: 1] running test loss: 0.1667, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.1071, running test accuracy: 0.9594
# test loss: 0.1188, accuracy: 0.9574
# elapsed time: 44.15258455276489
# [Epoch: 5 - Training]
# [Batch: 20] running train loss: 0.1192, running train accuracy: 0.9523
# [Batch: 40] running train loss: 0.1091, running train accuracy: 0.9570
# [Batch: 60] running train loss: 0.1083, running train accuracy: 0.9557
# [Batch: 80] running train loss: 0.1033, running train accuracy: 0.9584
# [Batch: 100] running train loss: 0.1023, running train accuracy: 0.9589
# [Batch: 120] running train loss: 0.1046, running train accuracy: 0.9585
# [Batch: 140] running train loss: 0.1024, running train accuracy: 0.9599
# [Batch: 160] running train loss: 0.1041, running train accuracy: 0.9600
# [Batch: 180] running train loss: 0.1022, running train accuracy: 0.9608
# [Batch: 200] running train loss: 0.1008, running train accuracy: 0.9617
# [Batch: 220] running train loss: 0.1004, running train accuracy: 0.9618
# [Batch: 240] running train loss: 0.1017, running train accuracy: 0.9611
# train loss: 0.1011, accuracy: 0.9610
# elapsed time: 356.1834468841553
# [Test]
# [Batch: 1] running test loss: 0.1357, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0730, running test accuracy: 0.9766
# test loss: 0.0691, accuracy: 0.9763
# elapsed time: 44.22489929199219
# [Epoch: 6 - Training]
# [Batch: 20] running train loss: 0.0852, running train accuracy: 0.9609
# [Batch: 40] running train loss: 0.0818, running train accuracy: 0.9648
# [Batch: 60] running train loss: 0.0847, running train accuracy: 0.9659
# [Batch: 80] running train loss: 0.0838, running train accuracy: 0.9668
# [Batch: 100] running train loss: 0.0830, running train accuracy: 0.9675
# [Batch: 120] running train loss: 0.0891, running train accuracy: 0.9658
# [Batch: 140] running train loss: 0.0857, running train accuracy: 0.9667
# [Batch: 160] running train loss: 0.0874, running train accuracy: 0.9665
# [Batch: 180] running train loss: 0.0892, running train accuracy: 0.9659
# [Batch: 200] running train loss: 0.0883, running train accuracy: 0.9658
# [Batch: 220] running train loss: 0.0866, running train accuracy: 0.9665
# [Batch: 240] running train loss: 0.0894, running train accuracy: 0.9656
# train loss: 0.0901, accuracy: 0.9652
# elapsed time: 355.05566143989563
# [Test]
# [Batch: 1] running test loss: 0.1143, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0636, running test accuracy: 0.9797
# test loss: 0.0668, accuracy: 0.9777
# elapsed time: 44.1911461353302
# [Epoch: 7 - Training]
# [Batch: 20] running train loss: 0.1399, running train accuracy: 0.9414
# [Batch: 40] running train loss: 0.1026, running train accuracy: 0.9566
# [Batch: 60] running train loss: 0.0985, running train accuracy: 0.9586
# [Batch: 80] running train loss: 0.1006, running train accuracy: 0.9598
# [Batch: 100] running train loss: 0.0983, running train accuracy: 0.9603
# [Batch: 120] running train loss: 0.0952, running train accuracy: 0.9613
# [Batch: 140] running train loss: 0.0951, running train accuracy: 0.9615
# [Batch: 160] running train loss: 0.0942, running train accuracy: 0.9617
# [Batch: 180] running train loss: 0.0936, running train accuracy: 0.9621
# [Batch: 200] running train loss: 0.0914, running train accuracy: 0.9634
# [Batch: 220] running train loss: 0.0915, running train accuracy: 0.9636
# [Batch: 240] running train loss: 0.0923, running train accuracy: 0.9636
# train loss: 0.0914, accuracy: 0.9640
# elapsed time: 355.93007588386536
# [Test]
# [Batch: 1] running test loss: 0.0812, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.0618, running test accuracy: 0.9781
# test loss: 0.0623, accuracy: 0.9763
# elapsed time: 44.32473540306091
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.0985, running train accuracy: 0.9633
# [Batch: 40] running train loss: 0.0859, running train accuracy: 0.9676
# [Batch: 60] running train loss: 0.0827, running train accuracy: 0.9682
# [Batch: 80] running train loss: 0.0784, running train accuracy: 0.9699
# [Batch: 100] running train loss: 0.0833, running train accuracy: 0.9683
# [Batch: 120] running train loss: 0.0825, running train accuracy: 0.9686
# [Batch: 140] running train loss: 0.0795, running train accuracy: 0.9691
# [Batch: 160] running train loss: 0.0790, running train accuracy: 0.9698
# [Batch: 180] running train loss: 0.0780, running train accuracy: 0.9701
# [Batch: 200] running train loss: 0.0786, running train accuracy: 0.9697
# [Batch: 220] running train loss: 0.0801, running train accuracy: 0.9695
# [Batch: 240] running train loss: 0.0784, running train accuracy: 0.9697
# train loss: 0.0773, accuracy: 0.9700
# elapsed time: 358.4871714115143
# [Test]
# [Batch: 1] running test loss: 0.1585, running test accuracy: 0.9531
# [Batch: 20] running test loss: 0.0645, running test accuracy: 0.9789
# test loss: 0.0778, accuracy: 0.9738
# elapsed time: 45.03624176979065
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.0874, running train accuracy: 0.9648
# [Batch: 40] running train loss: 0.0845, running train accuracy: 0.9664
# [Batch: 60] running train loss: 0.0798, running train accuracy: 0.9674
# [Batch: 80] running train loss: 0.0792, running train accuracy: 0.9686
# [Batch: 100] running train loss: 0.0815, running train accuracy: 0.9680
# [Batch: 120] running train loss: 0.0809, running train accuracy: 0.9677
# [Batch: 140] running train loss: 0.0781, running train accuracy: 0.9690
# [Batch: 160] running train loss: 0.0775, running train accuracy: 0.9694
# [Batch: 180] running train loss: 0.0755, running train accuracy: 0.9703
# [Batch: 200] running train loss: 0.0735, running train accuracy: 0.9709
# [Batch: 220] running train loss: 0.0735, running train accuracy: 0.9712
# [Batch: 240] running train loss: 0.0732, running train accuracy: 0.9712
# train loss: 0.0735, accuracy: 0.9711
# elapsed time: 363.4454824924469
# [Test]
# [Batch: 1] running test loss: 0.1101, running test accuracy: 0.9844
# [Batch: 20] running test loss: 0.0614, running test accuracy: 0.9820
# test loss: 0.0634, accuracy: 0.9787
# elapsed time: 45.27873778343201
# [Epoch: 10 - Training]
# [Batch: 20] running train loss: 0.0565, running train accuracy: 0.9820
# [Batch: 40] running train loss: 0.0641, running train accuracy: 0.9781
# [Batch: 60] running train loss: 0.0670, running train accuracy: 0.9779
# [Batch: 80] running train loss: 0.0625, running train accuracy: 0.9789
# [Batch: 100] running train loss: 0.0651, running train accuracy: 0.9778
# [Batch: 120] running train loss: 0.0634, running train accuracy: 0.9777
# [Batch: 140] running train loss: 0.0640, running train accuracy: 0.9771
# [Batch: 160] running train loss: 0.0656, running train accuracy: 0.9766
# [Batch: 180] running train loss: 0.0661, running train accuracy: 0.9767
# [Batch: 200] running train loss: 0.0655, running train accuracy: 0.9771
# [Batch: 220] running train loss: 0.0652, running train accuracy: 0.9774
# [Batch: 240] running train loss: 0.0670, running train accuracy: 0.9768
# train loss: 0.0668, accuracy: 0.9768
# elapsed time: 362.1680529117584
# [Test]
# [Batch: 1] running test loss: 0.1144, running test accuracy: 0.9844
# [Batch: 20] running test loss: 0.0604, running test accuracy: 0.9797
# test loss: 0.0618, accuracy: 0.9787
# elapsed time: 44.62477111816406

# %%
import matplotlib.pyplot as plt

train_losses, test_losses = zip(*history)
train_accuracies, test_accuracies = zip(*accuracy)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Test Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
test_acc = evaluation(retrained_model, test_dataloader)
unseen_acc = evaluation(retrained_model, unseen_dataloader_test)
mia = cal_mia(retrained_model.cuda(), unseen_dataloader_test)
print()
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.062, 'Acc': 0.9786924939467312}
# Unseen Acc: {'Loss': 0.096, 'Acc': 0.9675810473815462}
# MIA: {'MIA': 0.4901234567901235, 'Forgeting Score': 0.00987654320987652}
# Final Score: 0.9794697037634891
