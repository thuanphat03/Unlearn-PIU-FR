# %% [markdown]
# #### <b>Download the Original Datasets</b>
#
# * <b>CelebA-HQ Dataset</b>: A dataset consisting of 30,000 "human face" images.
#     * This dataset has approximately 3GB of data in size and is one of the most widely used face datasets worldwide.
# * <b>CelebA-HQ Identity Dataset</b>: A dataset that provides information about <b>who the individuals (subjects) are</b> for each facial image file.
# * <b>CelebA-HQ Attribute Dataset</b>: A dataset that provides attribute information for each facial image file.
#     * This attribute information includes <b>gender</b>, <b>smiling</b>, and <b>age</b>, which we will be used for a multi-label task.

# %%
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/Eb37jNPPA7hHl0fmktYqcV8B-qmPLx-ZKYQ1eFk4UPBV_A?download=1 -O CelebAMask-HQ.zip
# !wget https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVRoUY8_txRFv56-KWvZrksBDWbD6adkjBxwwRN7qAC6bg?download=1 -O CelebA-HQ-identity.txt
# !wget https://postechackr-my.sharepoint.com/:t:/g/personal/dongbinna_postech_ac_kr/EVrdIrPOkR1OlEWBVK8lE3AB9bFh741GnKBkNgPa8trNuA?download=1 -O CelebA-HQ-attribute.txt

# %%
# %%capture
# !rm -rf ./CelebAMask-HQ
# !unzip CelebAMask-HQ.zip

# %% [markdown]
# #### <b>Load Libraries</b>
#
# * Load various useful python libraries for the experiments.

# %%
import os
import time
import random
import glob
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, transforms, models
import torchvision.transforms.functional as TF
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from sklearn import linear_model, model_selection
from sklearn.utils import shuffle

# %%
def train(model, dataloader):
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Training]')
    model.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0
    log_step = 20

    for i, (imgs, labels) in enumerate(dataloader):
        imgs = imgs.cuda()
        labels = labels.cuda()

        outputs = model(imgs)
        optimizer.zero_grad()
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total += labels.size(0)
        running_loss += loss.item() * imgs.size(0)
        running_corrects += torch.sum(preds == labels)

        if (i + 1) % log_step == 0:
            current_loss = running_loss / total
            current_acc = running_corrects.double() / total
            print(f'[Batch: {i + 1}] running train loss: {current_loss:.4f}, running train accuracy: {current_acc:.4f}')

    epoch_loss = running_loss / total
    epoch_acc = running_corrects.double() / total
    print(f'train loss: {epoch_loss:.4f}, accuracy: {epoch_acc:.4f}')
    print("elapsed time:", time.time() - start_time)
    return epoch_loss, epoch_acc.item()


def test(model, dataloader):
    start_time = time.time()
    print('[Test]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0
    log_step=20

    for i, (imgs, labels) in enumerate(dataloader):
        imgs = imgs.cuda()
        labels = labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.size(0)
        running_loss += loss.item() * imgs.size(0)
        running_corrects += torch.sum(preds == labels)

        if (i == 0) or ((i + 1) % log_step == 0):
            current_loss = running_loss / total
            current_acc = running_corrects.double() / total
            print(f'[Batch: {i + 1}] running test loss: {current_loss:.4f}, running test accuracy: {current_acc:.4f}')

    epoch_loss = running_loss / total
    epoch_acc = running_corrects.double() / total
    print(f'test loss: {epoch_loss:.4f}, accuracy: {epoch_acc:.4f}')
    print("elapsed time:", time.time() - start_time)
    return epoch_loss, epoch_acc.item()

# %%
def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    random.seed(seed)

def compute_losses(net, loader):
    criterion = nn.CrossEntropyLoss(reduction="none")
    all_losses = []

    for inputs, labels in loader:
        targets = labels
        inputs, targets = inputs.cuda(), targets.cuda()

        logits = net(inputs)
        losses = criterion(logits, targets).cpu().detach().numpy()
            
        #losses = criterion(logits, targets).numpy(force=True)
        for l in losses:
            all_losses.append(l)

    return np.array(all_losses)

def simple_mia(sample_loss, members, n_splits=10, random_state=0):
    unique_members = np.unique(members)
    if not np.all(unique_members == np.array([0, 1])):
        raise ValueError("members should only have 0 and 1s")

    attack_model = linear_model.LogisticRegression()
    cv = model_selection.StratifiedShuffleSplit(
        n_splits=n_splits, random_state=random_state
    )
    return model_selection.cross_val_score(
        attack_model, sample_loss, members, cv=cv, scoring="accuracy"
    )


def cal_mia(model, unseen_dataloader):
    set_seed(42)

    forget_losses = compute_losses(model, forget_dataloader_test)
    unseen_losses = compute_losses(model, unseen_dataloader)

    np.random.shuffle(forget_losses)
    forget_losses = forget_losses[: len(unseen_losses)]

    samples_mia = np.concatenate((unseen_losses, forget_losses)).reshape((-1, 1))
    labels_mia = [0] * len(unseen_losses) + [1] * len(forget_losses)

    mia_scores = simple_mia(samples_mia, labels_mia)
    forgetting_score = abs(0.5 - mia_scores.mean())

    return {'MIA': mia_scores.mean(), 'Forgeting Score': forgetting_score}, unseen_losses, forget_losses

def plot_mia_scatter(unseen_losses, forget_losses):
    y_unseen = np.zeros(len(unseen_losses)) 
    y_forget = np.ones(len(forget_losses)) 

    # Vẽ đồ thị
    plt.figure(figsize=(8, 5))
    plt.scatter(unseen_losses, y_unseen, color='skyblue', label='Unseen dataset (Class 0)', alpha=0.6)
    plt.scatter(forget_losses, y_forget, color='lightcoral', label='Forget dataset (Class 1)', alpha=0.6)

    # Cài đặt trục
    plt.xlabel("Loss Value")
    plt.ylabel("Class")
    plt.title("Showing Model's Recognition of Unseen and Forget Datasets")
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)
    plt.grid(alpha=0.3)
    plt.show()


@torch.no_grad()
def evaluation(model, data_loader):
    model.eval()
    with torch.no_grad():
        running_loss = 0.
        running_corrects = 0

        for inputs, labels in data_loader:
            inputs = inputs.cuda()
            labels = labels.cuda()

            outputs = model(inputs)  # Use the passed model argument here
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        # Use data_loader's dataset length for normalization
        epoch_loss = running_loss / len(data_loader.dataset)
        epoch_loss = round(epoch_loss, 3)
        epoch_acc = running_corrects.item() / len(data_loader.dataset)

        return {'Loss': epoch_loss, 'Acc': epoch_acc}

# %% [markdown]
# #### <b>Load Identity Mapping</b>
# * Check which person each file name is associated with.
# * There are a total of 6,217 individuals (subjects) among the 30,000 files.

# %%
path = "./celeb_dataset/"

# %%
identities = {}

# (Image File Name, Subject Identity Information)
with open(path + 'CelebA-HQ-identity.txt') as f:
    lines = f.readlines()
    for line in lines:
        file_name, identity = line.strip().split()
        identities[file_name] = identity

print(f'There are {len(set(identities.values()))} identities.')
print(f'There are {len(identities.keys())} images.')
# Out:
# There are 6217 identities.
# There are 30000 images.

# %% [markdown]
# #### <b>Choose Single Label to Use</b>
# * "male": 21,
# * "smiling": 32,
# * "young": 40

# %%
label_map = {}

label_num = 40  # "male": 21, "smiling": 32, "young": 40

with open(path + 'CelebA-HQ-attribute.txt') as f:
    lines = f.readlines()
    for line in lines[2:]:
        splited = line.strip().split()
        file_name, label = splited[0], splited[label_num]
        label_map[file_name] = label

print(f'There are {len(set(label_map.values()))} classes.')
print(f'There are {len(label_map.keys())} images.')
# Out:
# There are 2 classes.
# There are 30000 images.

# %% [markdown]
# #### <b>Split the Dataset</b>
# * <b>Training dataset  $\mathcal{D}_{train}$</b>: 25,933 images.
# * <b>Test dataset $\mathcal{D}_{test}$</b>: 2,065 images.
# * <b>Unseen dataset $\mathcal{D}_{unseen}$</b>: 2,002 images.

# %%
source_root = path + 'CelebAMask-HQ/CelebA-HQ-img/'

train_index = 190
retrain_index = 1250
unseen_index = 4855

# %%
class TrainDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity >= train_index and identity < unseen_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class TestDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []
        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < train_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class ForgetDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity >= train_index and identity < retrain_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class RetrainDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        self.transform = transform

        self.image_paths = []
        self.labels = []

        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index and identity >= retrain_index:
                label = int(label_map[file_name])
                if label == -1: label = 0
                self.labels.append((label, identity))
                self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class UnseenDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None, train=False, test=False):
        self.image_path_list = glob.glob(os.path.join(source_root, "*"))
        # Shuffle the list of image paths
        self.image_path_list = shuffle(self.image_path_list, random_state=42)

        self.transform = transform

        self.image_paths = []
        self.labels = []
        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0
            self.labels.append((label, identity))
            self.image_paths.append(image_path)

        if train:
            self.labels = self.labels[:int(len(self.labels) * 0.8)]
            self.image_paths = self.image_paths[:int(len(self.image_paths) * 0.8)]
        elif test:
            self.labels = self.labels[int(len(self.labels) * 0.8):]
            self.image_paths = self.image_paths[int(len(self.image_paths) * 0.8):]

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
train_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.RandomHorizontalFlip(),
    transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
    transforms.ToTensor()
])

test_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.ToTensor()
])

unseen_transform = transforms.Compose([
    transforms.Resize(128),
    transforms.ToTensor()
])

train_set = TrainDataset(transform=train_transform)
test_set = TestDataset(transform=test_transform)
forget_set_train = ForgetDataset(transform=train_transform)
forget_set_test = ForgetDataset(transform=test_transform)
retrain_set_train = RetrainDataset(transform=train_transform)
retrain_set_test = RetrainDataset(transform=test_transform)
unseen_set_train = UnseenDataset(transform=unseen_transform, train=True, test=False)
unseen_set_test = UnseenDataset(transform=unseen_transform, train=False, test=True)

# %%
print('Train dataset size:', len(train_set))
print('Test dataset size:', len(test_set))
print('Forget dataset size:', len(forget_set_train))
print('Retrain dataset size:', len(retrain_set_train))
print('Train Unseen dataset size:', len(unseen_set_train))
print('Test Unseen dataset size:', len(unseen_set_test))
# Out:
# Train dataset size: 25933
# Test dataset size: 2065
# Forget dataset size: 10183
# Retrain dataset size: 15750
# Train Unseen dataset size: 1601
# Test Unseen dataset size: 401

# %% [markdown]
# * In the NeurIPS Competition setting, when performing machine unlearning, training is done with 'retrain' and 'forget', so augmentation can be applied. However, it should never be applied during evaluation.

# %%
train_dataloader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True, pin_memory=True)
test_dataloader = torch.utils.data.DataLoader(test_set, batch_size=64, shuffle=False, pin_memory=True)
forget_dataloader_train = torch.utils.data.DataLoader(forget_set_train, batch_size=64, shuffle=False, pin_memory=True)
forget_dataloader_test = torch.utils.data.DataLoader(forget_set_test, batch_size=64, shuffle=False, pin_memory=True)
retrain_dataloader_train = torch.utils.data.DataLoader(retrain_set_train, batch_size=64, shuffle=True, pin_memory=True)
retrain_dataloader_test = torch.utils.data.DataLoader(retrain_set_test, batch_size=64, shuffle=False,pin_memory=True)
unseen_dataloader_train = torch.utils.data.DataLoader(unseen_set_train, batch_size=64, shuffle=False, pin_memory=True)
unseen_dataloader_test = torch.utils.data.DataLoader(unseen_set_test, batch_size=64, shuffle=False, pin_memory=True)

# %%
train_image_paths = TrainDataset().image_paths
test_image_paths = TestDataset().image_paths
forget_image_paths = ForgetDataset().image_paths
retrain_image_paths = RetrainDataset().image_paths
unseen_image_paths = UnseenDataset(train=True).image_paths

train_test_overlap = len(set(train_image_paths) & set(test_image_paths))
train_forget_overlap = len(set(train_image_paths) & set(forget_image_paths))
train_retrain_overlap = len(set(train_image_paths) & set(retrain_image_paths))
train_unseen_overlap = len(set(train_image_paths) & set(unseen_image_paths))
test_forget_overlap = len(set(test_image_paths) & set(forget_image_paths))
test_retrain_overlap = len(set(test_image_paths) & set(retrain_image_paths))
test_unseen_overlap = len(set(test_image_paths) & set(unseen_image_paths))
forget_retrain_overlap = len(set(forget_image_paths) & set(retrain_image_paths))
forget_unseen_overlap = len(set(forget_image_paths) & set(unseen_image_paths))
retrain_unseen_overlap = len(set(retrain_image_paths) & set(unseen_image_paths))

overlap_dict = {
    'train_test': train_test_overlap,
    'train_forget': train_forget_overlap,
    'train_retrain': train_retrain_overlap,
    'train_unseen': train_unseen_overlap,
    'test_forget': test_forget_overlap,
    'test_retrain': test_retrain_overlap,
    'test_unseen': test_unseen_overlap,
    'forget_retrain': forget_retrain_overlap,
    'forget_unseen': forget_unseen_overlap,
    'retrain_unseen': retrain_unseen_overlap
}
overlap_dict
# Out:
# {'train_test': 0,
#  'train_forget': 10183,
#  'train_retrain': 15750,
#  'train_unseen': 0,
#  'test_forget': 0,
#  'test_retrain': 0,
#  'test_unseen': 0,
#  'forget_retrain': 0,
#  'forget_unseen': 0,
#  'retrain_unseen': 0}

# %% [markdown]
# #### <b>Imgae Visualization</b>

# %%
if label_num == 21:
    label_convert = {0: "F", 1: "M"}
elif label_num == 32:
    label_convert = {0: "unsmiling", 1: "smiling"}
if label_num == 40:
    label_convert = {0: "old", 1: "young"}

# %%
def show_images(images, labels, nrow=6, save_path=None):
    n_images = len(images)
    nrows = n_images // nrow + (n_images % nrow > 0)

    fig, axs = plt.subplots(nrows, nrow, figsize=(14.5, 2.3 * nrows), frameon=False)
    axs = axs.flatten() if n_images > 1 else [axs]

    for idx, (img, label) in enumerate(zip(images, labels)):
        ax = axs[idx]
        img_np = img.numpy().transpose((1, 2, 0))
        ax.imshow(img_np)
        ax.axis('off')

        ax.text(5, 5, label, color='white', fontsize=13,  ha='left', va='top',
                bbox=dict(facecolor='black', alpha=0.5, boxstyle='round,pad=0.1'))

    plt.tight_layout(pad=0)

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)

    plt.show()

iterator = iter(test_dataloader)
imgs, labels = next(iterator)

label_strs = [label_convert[label.item()] for label in labels[0:12]]

show_images(imgs[0:12], label_strs, nrow=6)

# %% [markdown]
# # Train original model

# %%
learning_rate = 0.01
log_step = 30

model = models.resnet18(pretrained=False)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
history = []
accuracy = []
num_original_epochs = 9
for epoch in range(num_original_epochs):
    train_loss, train_acc = train(model, train_dataloader)
    test_loss, test_acc = test(model, test_dataloader)
    history.append((train_loss, test_loss))
    accuracy.append((train_acc, test_acc))1

torch.save(model.state_dict(), f'last_checkpoint_epoch_{num_original_epochs}_young.pth')
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.6090, running train accuracy: 0.7328
# [Batch: 40] running train loss: 0.6011, running train accuracy: 0.7387
# [Batch: 60] running train loss: 0.5777, running train accuracy: 0.7552
# [Batch: 80] running train loss: 0.5679, running train accuracy: 0.7574
# [Batch: 100] running train loss: 0.5607, running train accuracy: 0.7556
# [Batch: 120] running train loss: 0.5455, running train accuracy: 0.7626
# [Batch: 140] running train loss: 0.5405, running train accuracy: 0.7623
# [Batch: 160] running train loss: 0.5359, running train accuracy: 0.7653
# [Batch: 180] running train loss: 0.5295, running train accuracy: 0.7678
# [Batch: 200] running train loss: 0.5314, running train accuracy: 0.7651
# [Batch: 220] running train loss: 0.5290, running train accuracy: 0.7678
# [Batch: 240] running train loss: 0.5266, running train accuracy: 0.7688
# [Batch: 260] running train loss: 0.5224, running train accuracy: 0.7694
# [Batch: 280] running train loss: 0.5199, running train accuracy: 0.7701
# [Batch: 300] running train loss: 0.5147, running train accuracy: 0.7734
# [Batch: 320] running train loss: 0.5138, running train accuracy: 0.7748
# [Batch: 340] running train loss: 0.5171, running train accuracy: 0.7744
# [Batch: 360] running train loss: 0.5138, running train accuracy: 0.7760
# [Batch: 380] running train loss: 0.5141, running train accuracy: 0.7770
# [Batch: 400] running train loss: 0.5164, running train accuracy: 0.7761
# train loss: 0.5162, accuracy: 0.7764
# elapsed time: 735.575846195221
# [Test]
# [Batch: 1] running test loss: 1.2813, running test accuracy: 0.2656
# [Batch: 20] running test loss: 1.3233, running test accuracy: 0.2227
# test loss: 1.3451, accuracy: 0.2150
# elapsed time: 46.75151443481445
# [Epoch: 2 - Training]
# [Batch: 20] running train loss: 0.5019, running train accuracy: 0.7852
# [Batch: 40] running train loss: 0.4522, running train accuracy: 0.8047
# [Batch: 60] running train loss: 0.4403, running train accuracy: 0.8081
# [Batch: 80] running train loss: 0.4302, running train accuracy: 0.8094
# [Batch: 100] running train loss: 0.4268, running train accuracy: 0.8113
# [Batch: 120] running train loss: 0.4261, running train accuracy: 0.8116
# [Batch: 140] running train loss: 0.4276, running train accuracy: 0.8102
# [Batch: 160] running train loss: 0.4254, running train accuracy: 0.8133
# [Batch: 180] running train loss: 0.4238, running train accuracy: 0.8139
# [Batch: 200] running train loss: 0.4194, running train accuracy: 0.8160
# [Batch: 220] running train loss: 0.4181, running train accuracy: 0.8165
# [Batch: 240] running train loss: 0.4165, running train accuracy: 0.8171
# [Batch: 260] running train loss: 0.4131, running train accuracy: 0.8197
# [Batch: 280] running train loss: 0.4220, running train accuracy: 0.8176
# [Batch: 300] running train loss: 0.4251, running train accuracy: 0.8175
# [Batch: 320] running train loss: 0.4265, running train accuracy: 0.8169
# [Batch: 340] running train loss: 0.4245, running train accuracy: 0.8179
# [Batch: 360] running train loss: 0.4225, running train accuracy: 0.8187
# [Batch: 380] running train loss: 0.4205, running train accuracy: 0.8202
# [Batch: 400] running train loss: 0.4195, running train accuracy: 0.8206
# train loss: 0.4189, accuracy: 0.8207
# elapsed time: 686.1401946544647
# [Test]
# [Batch: 1] running test loss: 0.2511, running test accuracy: 0.9062
# [Batch: 20] running test loss: 0.3508, running test accuracy: 0.8727
# test loss: 0.3268, accuracy: 0.8765
# elapsed time: 43.98516035079956
# [Epoch: 3 - Training]
# [Batch: 20] running train loss: 0.3712, running train accuracy: 0.8359
# [Batch: 40] running train loss: 0.3696, running train accuracy: 0.8352
# [Batch: 60] running train loss: 0.3644, running train accuracy: 0.8419
# [Batch: 80] running train loss: 0.3694, running train accuracy: 0.8406
# [Batch: 100] running train loss: 0.3817, running train accuracy: 0.8352
# [Batch: 120] running train loss: 0.3799, running train accuracy: 0.8379
# [Batch: 140] running train loss: 0.3785, running train accuracy: 0.8374
# [Batch: 160] running train loss: 0.3793, running train accuracy: 0.8375
# [Batch: 180] running train loss: 0.3800, running train accuracy: 0.8363
# [Batch: 200] running train loss: 0.3817, running train accuracy: 0.8371
# [Batch: 220] running train loss: 0.3835, running train accuracy: 0.8373
# [Batch: 240] running train loss: 0.3770, running train accuracy: 0.8402
# [Batch: 260] running train loss: 0.3761, running train accuracy: 0.8416
# [Batch: 280] running train loss: 0.3774, running train accuracy: 0.8415
# [Batch: 300] running train loss: 0.3754, running train accuracy: 0.8422
# [Batch: 320] running train loss: 0.3755, running train accuracy: 0.8419
# [Batch: 340] running train loss: 0.3757, running train accuracy: 0.8420
# [Batch: 360] running train loss: 0.3746, running train accuracy: 0.8421
# [Batch: 380] running train loss: 0.3740, running train accuracy: 0.8423
# [Batch: 400] running train loss: 0.3748, running train accuracy: 0.8419
# train loss: 0.3741, accuracy: 0.8422
# elapsed time: 707.834972858429
# [Test]
# [Batch: 1] running test loss: 0.5504, running test accuracy: 0.6875
# [Batch: 20] running test loss: 0.6131, running test accuracy: 0.6648
# test loss: 0.6156, accuracy: 0.6678
# elapsed time: 41.52802395820618
# [Epoch: 4 - Training]
# [Batch: 20] running train loss: 0.3500, running train accuracy: 0.8438
# [Batch: 40] running train loss: 0.3514, running train accuracy: 0.8461
# [Batch: 60] running train loss: 0.3593, running train accuracy: 0.8461
# [Batch: 80] running train loss: 0.3616, running train accuracy: 0.8449
# [Batch: 100] running train loss: 0.3600, running train accuracy: 0.8469
# [Batch: 120] running train loss: 0.3553, running train accuracy: 0.8497
# [Batch: 140] running train loss: 0.3490, running train accuracy: 0.8541
# [Batch: 160] running train loss: 0.3493, running train accuracy: 0.8546
# [Batch: 180] running train loss: 0.3478, running train accuracy: 0.8544
# [Batch: 200] running train loss: 0.3461, running train accuracy: 0.8548
# [Batch: 220] running train loss: 0.3448, running train accuracy: 0.8563
# [Batch: 240] running train loss: 0.3417, running train accuracy: 0.8577
# [Batch: 260] running train loss: 0.3422, running train accuracy: 0.8561
# [Batch: 280] running train loss: 0.3411, running train accuracy: 0.8568
# [Batch: 300] running train loss: 0.3388, running train accuracy: 0.8577
# [Batch: 320] running train loss: 0.3375, running train accuracy: 0.8580
# [Batch: 340] running train loss: 0.3385, running train accuracy: 0.8582
# [Batch: 360] running train loss: 0.3375, running train accuracy: 0.8587
# [Batch: 380] running train loss: 0.3379, running train accuracy: 0.8588
# [Batch: 400] running train loss: 0.3381, running train accuracy: 0.8588
# train loss: 0.3379, accuracy: 0.8589
# elapsed time: 586.1184389591217
# [Test]
# [Batch: 1] running test loss: 0.3807, running test accuracy: 0.8594
# [Batch: 20] running test loss: 0.4861, running test accuracy: 0.8609
# test loss: 0.4442, accuracy: 0.8707
# elapsed time: 41.86282753944397
# [Epoch: 5 - Training]
# [Batch: 20] running train loss: 0.3260, running train accuracy: 0.8617
# [Batch: 40] running train loss: 0.3278, running train accuracy: 0.8668
# [Batch: 60] running train loss: 0.3182, running train accuracy: 0.8685
# [Batch: 80] running train loss: 0.3186, running train accuracy: 0.8678
# [Batch: 100] running train loss: 0.3278, running train accuracy: 0.8650
# [Batch: 120] running train loss: 0.3261, running train accuracy: 0.8661
# [Batch: 140] running train loss: 0.3266, running train accuracy: 0.8657
# [Batch: 160] running train loss: 0.3265, running train accuracy: 0.8647
# [Batch: 180] running train loss: 0.3259, running train accuracy: 0.8648
# [Batch: 200] running train loss: 0.3244, running train accuracy: 0.8648
# [Batch: 220] running train loss: 0.3266, running train accuracy: 0.8634
# [Batch: 240] running train loss: 0.3281, running train accuracy: 0.8626
# [Batch: 260] running train loss: 0.3291, running train accuracy: 0.8626
# [Batch: 280] running train loss: 0.3325, running train accuracy: 0.8619
# [Batch: 300] running train loss: 0.3316, running train accuracy: 0.8634
# [Batch: 320] running train loss: 0.3291, running train accuracy: 0.8643
# [Batch: 340] running train loss: 0.3274, running train accuracy: 0.8653
# [Batch: 360] running train loss: 0.3262, running train accuracy: 0.8655
# [Batch: 380] running train loss: 0.3276, running train accuracy: 0.8650
# [Batch: 400] running train loss: 0.3284, running train accuracy: 0.8645
# train loss: 0.3293, accuracy: 0.8639
# elapsed time: 601.6647424697876
# [Test]
# [Batch: 1] running test loss: 0.3510, running test accuracy: 0.9531
# [Batch: 20] running test loss: 0.4018, running test accuracy: 0.8602
# test loss: 0.3997, accuracy: 0.8615
# elapsed time: 48.11554455757141
# [Epoch: 6 - Training]
# [Batch: 20] running train loss: 0.2925, running train accuracy: 0.8734
# [Batch: 40] running train loss: 0.3070, running train accuracy: 0.8715
# [Batch: 60] running train loss: 0.3044, running train accuracy: 0.8727
# [Batch: 80] running train loss: 0.3055, running train accuracy: 0.8719
# [Batch: 100] running train loss: 0.3113, running train accuracy: 0.8706
# [Batch: 120] running train loss: 0.3115, running train accuracy: 0.8719
# [Batch: 140] running train loss: 0.3130, running train accuracy: 0.8713
# [Batch: 160] running train loss: 0.3115, running train accuracy: 0.8711
# [Batch: 180] running train loss: 0.3106, running train accuracy: 0.8715
# [Batch: 200] running train loss: 0.3102, running train accuracy: 0.8720
# [Batch: 220] running train loss: 0.3095, running train accuracy: 0.8724
# [Batch: 240] running train loss: 0.3101, running train accuracy: 0.8732
# [Batch: 260] running train loss: 0.3108, running train accuracy: 0.8722
# [Batch: 280] running train loss: 0.3111, running train accuracy: 0.8717
# [Batch: 300] running train loss: 0.3108, running train accuracy: 0.8717
# [Batch: 320] running train loss: 0.3121, running train accuracy: 0.8707
# [Batch: 340] running train loss: 0.3116, running train accuracy: 0.8710
# [Batch: 360] running train loss: 0.3104, running train accuracy: 0.8711
# [Batch: 380] running train loss: 0.3105, running train accuracy: 0.8713
# [Batch: 400] running train loss: 0.3108, running train accuracy: 0.8714
# train loss: 0.3110, accuracy: 0.8714
# elapsed time: 618.0268635749817
# [Test]
# [Batch: 1] running test loss: 0.2748, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.2909, running test accuracy: 0.8875
# test loss: 0.2739, accuracy: 0.8969
# elapsed time: 48.26075482368469
# [Epoch: 7 - Training]
# [Batch: 20] running train loss: 0.3017, running train accuracy: 0.8664
# [Batch: 40] running train loss: 0.3115, running train accuracy: 0.8676
# [Batch: 60] running train loss: 0.3123, running train accuracy: 0.8643
# [Batch: 80] running train loss: 0.3094, running train accuracy: 0.8680
# [Batch: 100] running train loss: 0.3025, running train accuracy: 0.8725
# [Batch: 120] running train loss: 0.3058, running train accuracy: 0.8717
# [Batch: 140] running train loss: 0.3069, running train accuracy: 0.8728
# [Batch: 160] running train loss: 0.3108, running train accuracy: 0.8715
# [Batch: 180] running train loss: 0.3112, running train accuracy: 0.8710
# [Batch: 200] running train loss: 0.3087, running train accuracy: 0.8726
# [Batch: 220] running train loss: 0.3102, running train accuracy: 0.8719
# [Batch: 240] running train loss: 0.3113, running train accuracy: 0.8712
# [Batch: 260] running train loss: 0.3120, running train accuracy: 0.8703
# [Batch: 280] running train loss: 0.3099, running train accuracy: 0.8713
# [Batch: 300] running train loss: 0.3084, running train accuracy: 0.8719
# [Batch: 320] running train loss: 0.3060, running train accuracy: 0.8725
# [Batch: 340] running train loss: 0.3053, running train accuracy: 0.8727
# [Batch: 360] running train loss: 0.3044, running train accuracy: 0.8737
# [Batch: 380] running train loss: 0.3048, running train accuracy: 0.8730
# [Batch: 400] running train loss: 0.3045, running train accuracy: 0.8732
# train loss: 0.3041, accuracy: 0.8732
# elapsed time: 623.8101642131805
# [Test]
# [Batch: 1] running test loss: 0.1650, running test accuracy: 0.9688
# [Batch: 20] running test loss: 0.2593, running test accuracy: 0.8930
# test loss: 0.2474, accuracy: 0.9007
# elapsed time: 48.23586869239807
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.3362, running train accuracy: 0.8633
# [Batch: 40] running train loss: 0.3069, running train accuracy: 0.8734
# [Batch: 60] running train loss: 0.2974, running train accuracy: 0.8760
# [Batch: 80] running train loss: 0.2871, running train accuracy: 0.8820
# [Batch: 100] running train loss: 0.2847, running train accuracy: 0.8819
# [Batch: 120] running train loss: 0.2883, running train accuracy: 0.8806
# [Batch: 140] running train loss: 0.2890, running train accuracy: 0.8791
# [Batch: 160] running train loss: 0.2908, running train accuracy: 0.8793
# [Batch: 180] running train loss: 0.2931, running train accuracy: 0.8784
# [Batch: 200] running train loss: 0.2932, running train accuracy: 0.8778
# [Batch: 220] running train loss: 0.2917, running train accuracy: 0.8781
# [Batch: 240] running train loss: 0.2906, running train accuracy: 0.8792
# [Batch: 260] running train loss: 0.2906, running train accuracy: 0.8784
# [Batch: 280] running train loss: 0.2923, running train accuracy: 0.8776
# [Batch: 300] running train loss: 0.2916, running train accuracy: 0.8783
# [Batch: 320] running train loss: 0.2915, running train accuracy: 0.8786
# [Batch: 340] running train loss: 0.2941, running train accuracy: 0.8780
# [Batch: 360] running train loss: 0.2943, running train accuracy: 0.8781
# [Batch: 380] running train loss: 0.2955, running train accuracy: 0.8775
# [Batch: 400] running train loss: 0.2953, running train accuracy: 0.8780
# train loss: 0.2957, accuracy: 0.8778
# elapsed time: 666.1002645492554
# [Test]
# [Batch: 1] running test loss: 0.2122, running test accuracy: 0.9062
# [Batch: 20] running test loss: 0.2891, running test accuracy: 0.8938
# test loss: 0.2695, accuracy: 0.9007
# elapsed time: 55.442047357559204
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.2735, running train accuracy: 0.8852
# [Batch: 40] running train loss: 0.2917, running train accuracy: 0.8816
# [Batch: 60] running train loss: 0.2837, running train accuracy: 0.8867
# [Batch: 80] running train loss: 0.2805, running train accuracy: 0.8896
# [Batch: 100] running train loss: 0.2833, running train accuracy: 0.8859
# [Batch: 120] running train loss: 0.2810, running train accuracy: 0.8859
# [Batch: 140] running train loss: 0.2808, running train accuracy: 0.8852
# [Batch: 160] running train loss: 0.2807, running train accuracy: 0.8850
# [Batch: 180] running train loss: 0.2818, running train accuracy: 0.8841
# [Batch: 200] running train loss: 0.2805, running train accuracy: 0.8848
# [Batch: 220] running train loss: 0.2794, running train accuracy: 0.8850
# [Batch: 240] running train loss: 0.2811, running train accuracy: 0.8842
# [Batch: 260] running train loss: 0.2819, running train accuracy: 0.8842
# [Batch: 280] running train loss: 0.2816, running train accuracy: 0.8837
# [Batch: 300] running train loss: 0.2822, running train accuracy: 0.8835
# [Batch: 320] running train loss: 0.2821, running train accuracy: 0.8837
# [Batch: 340] running train loss: 0.2830, running train accuracy: 0.8838
# [Batch: 360] running train loss: 0.2820, running train accuracy: 0.8840
# [Batch: 380] running train loss: 0.2828, running train accuracy: 0.8843
# [Batch: 400] running train loss: 0.2838, running train accuracy: 0.8834
# train loss: 0.2830, accuracy: 0.8837
# elapsed time: 651.207170009613
# [Test]
# [Batch: 1] running test loss: 0.2761, running test accuracy: 0.8906
# [Batch: 20] running test loss: 0.3551, running test accuracy: 0.8523
# test loss: 0.3611, accuracy: 0.8460
# elapsed time: 46.66958284378052

# %%
import matplotlib.pyplot as plt

train_losses, test_losses = zip(*history)
train_accuracies, test_accuracies = zip(*accuracy)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Test Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Forgetting Functions

# %%
random.seed(42)

# %% [markdown]
# # Stage 1: Forgetting via PIU-FR

# %%
# original_save_path = f'last_checkpoint_epoch_{num_original_epochs}_gender.pth' # If you trian the original model from scratch.
original_save_path = f'last_checkpoint_epoch_10_young.pth'  # downloaded model
original_model = models.resnet18(pretrained=False)
num_features = original_model.fc.in_features
original_model.fc = nn.Linear(num_features, 2)
original_model = original_model.cuda()
original_model.load_state_dict(torch.load(original_save_path))
criterion = nn.CrossEntropyLoss()

# %%
# Performance
log_step = 30
test_acc = evaluation(original_model, test_dataloader)
unseen_acc = evaluation(original_model, unseen_dataloader_test)
mia, unseen_losses, forget_losses = cal_mia(original_model.cuda(), unseen_dataloader_test)
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.312, 'Acc': 0.8760290556900726}
# Unseen Acc: {'Loss': 0.48, 'Acc': 0.773067331670823}
# MIA: {'MIA': 0.5333333333333333, 'Forgeting Score': 0.033333333333333326}
# Final Score: 0.904681194511703

# %%
# original_save_path = f'last_checkpoint_epoch_{num_original_epochs}_gender.pth' # If you trian the original model from scratch.
original_save_path = f'last_checkpoint_epoch_10_young.pth'  # downloaded model
forgot_model = models.resnet18(pretrained=False)
num_features = forgot_model.fc.in_features
forgot_model.fc = nn.Linear(num_features, 2)
forgot_model = forgot_model.cuda()
forgot_model.load_state_dict(torch.load(original_save_path))
criterion = nn.CrossEntropyLoss()

# %%
class DistillKL(nn.Module):
    def __init__(self, T):
        super(DistillKL, self).__init__()
        self.T = T

    def forward(self, y_s, y_t):
        p_s = F.log_softmax(y_s/self.T, dim=1)
        p_t = F.softmax(y_t/self.T, dim=1)
        loss = F.kl_div(p_s, p_t, size_average=False) * (self.T**2) / y_s.shape[0]
        return loss

# %%
class NewUnseenDataset(torch.utils.data.Dataset):
    def __init__(self, transform=None, unseen_set_train=None, forget_dataloader=None):
        self.transform = transform

        self.image_paths = []
        self.labels = []
        self.unseen_set_train = unseen_set_train
        self.image_path_list = self.unseen_set_train.image_paths
        self.forget_dataloader = forget_dataloader

        # Create a dict consist of image_path follow gender, smilling and young
        dict_labels_path = {}
        for image_path in self.image_path_list:
            image_path = image_path.replace("\\", "/")
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0

            # Use the (gender, smiling, young) tuple as the dictionary key
            key = label

            # Check if the key exists in the dictionary
            if key in dict_labels_path:
                dict_labels_path[key].append(image_path)
            else:
                dict_labels_path[key] = [image_path]

        # Create a new image_list
        new_image_list = []

        for i, (inputs_forget, label) in enumerate(self.forget_dataloader):
            # Convert labels to the same format as the outputs (float).
            labels_forget = label.cuda()
            
            for label in labels_forget:
                # Convert tensor label to tuple for dictionary key
                key = int(label)
                
                # Ensure the key exists in the dictionary
                if key in dict_labels_path and dict_labels_path[key]:
                    # Randomly select a sample from the list associated with this key
                    chosen_sample = random.choice(dict_labels_path[key])
                    new_image_list.append(chosen_sample)
                else:
                    # Handle the case where the key does not exist or has no associated samples
                    print(f"No samples found for key {key}")

        self.image_path_list = new_image_list

        for image_path in self.image_path_list:
            file_name = image_path.split('/')[-1]
            identity = int(identities[file_name])
            if identity < unseen_index:
                continue
            label = int(label_map[file_name])
            if label == -1: label = 0
         
            self.labels.append((label, identity))
            self.image_paths.append(image_path)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")
        label = self.labels[idx]

        if self.transform:
            image = self.transform(image)
        label = torch.tensor(label[0])

        return image, label

# %%
class PIU_FR:
    def __init__(self, original_model, forgot_model, unseen_set_train, forget_dataloader):
        self.original_model = original_model
        self.forgot_model = forgot_model
        self.forget_dataloader = forget_dataloader
        self.unseen_set_train = unseen_set_train
        self.criterion_div = DistillKL(4.0)
        self.optimizer = optim.SGD(self.forgot_model.parameters(), lr=0.001)
        self.criterion = torch.nn.CrossEntropyLoss()

    def train_epoch(self):
        set_seed(42)
        self.forgot_model.train()
        self.original_model.eval()

        # Function to compute accuracy.
        def compute_accuracy(outputs, labels):
            _, predicted = outputs.max(1)
            total = labels.size(0)
            correct = predicted.eq(labels).sum().item()
            return 100 * correct / total

        total_loss_div, total_accuracy_forget = 0, 0
        
        # Process new unseen_dataloader
        new_unseen_dataset = NewUnseenDataset(unseen_transform, unseen_set_train=self.unseen_set_train, forget_dataloader=self.forget_dataloader)
        new_unseen_dataloader = DataLoader(new_unseen_dataset, batch_size=64, shuffle=False)
        
        # Training with unseen data.
        flag = 1

        for (inputs_unseen, labels_unseen), (inputs_forget, labels_forget) in zip(new_unseen_dataloader, self.forget_dataloader):
            inputs_unseen, labels_unseen = inputs_unseen.cuda(), labels_unseen.cuda()
            inputs_forget, labels_forget = inputs_forget.cuda(), labels_forget.cuda()

            outputs_forget = self.forgot_model(inputs_forget)

            with torch.no_grad():
                outputs_unseen = self.original_model(inputs_unseen)

            # Loss computation
            loss_div = flag * self.criterion_div(outputs_forget, outputs_unseen)

            # Update total loss and accuracy for unseen data.
            total_loss_div += loss_div.item()
            total_accuracy_forget += compute_accuracy(outputs_forget, labels_forget)

            # Backward pass
            self.optimizer.zero_grad()
            loss_div.backward()
            self.optimizer.step()
            
            if flag == 1:
                flag = -1
            else:
                flag = 1

        # Print average loss and accuracy for the entire epoch
        avg_loss_div = total_loss_div / len(self.forget_dataloader)
        avg_accuracy_forget = total_accuracy_forget / len(self.forget_dataloader)

        mia = cal_mia(self.forgot_model.cuda(), unseen_dataloader_train)

        print(f'Epoch unseen: Avg Loss: {avg_loss_div:.4f}, Avg Accuracy: {avg_accuracy_forget:.2f}, Forgeting Score: {mia["Forgeting Score"]}')

# %%
set_seed(42)

# Initialize and train
forgetting_trainer = PIU_FR(original_model, forgot_model, unseen_set_train, forget_dataloader_train)

num_epochs = 2
for epoch in range(num_epochs):
    forgetting_trainer.train_epoch()
    print(f"Epoch {epoch+1} completed.")
# Out:
# Epoch unseen: Avg Loss: 0.0425, Avg Accuracy: 89.08, Forgeting Score: 0.016822429906541925
# Epoch 1 completed.
# Epoch unseen: Avg Loss: 0.0147, Avg Accuracy: 88.22, Forgeting Score: 0.0037383177570093906
# Epoch 2 completed.

# %%
# Performance
log_step = 30
test_acc = evaluation(forgot_model, test_dataloader)
unseen_acc = evaluation(forgot_model, unseen_dataloader_test)
mia = cal_mia(forgot_model.cuda(), unseen_dataloader_test)
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.292, 'Acc': 0.9075060532687651}
# Unseen Acc: {'Loss': 0.362, 'Acc': 0.8703241895261845}
# MIA: {'MIA': 0.5444444444444445, 'Forgeting Score': 0.04444444444444451}
# Final Score: 0.909308582189938

# %% [markdown]
# # Stage 2: Improve accuracy (Optional)

# %%
num_epochs = 3
learning_rate = 0.01
log_step = 30

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(forgot_model.parameters(), lr=learning_rate, momentum=0.9)

for epoch in range(num_epochs):
   train_loss, train_acc = train(forgot_model, retrain_dataloader_train)
   test_loss, test_acc = test(forgot_model, test_dataloader)

# %%
#Performance
log_step = 30
test_acc = evaluation(forgot_model, test_dataloader)
unseen_acc = evaluation(forgot_model, unseen_dataloader_test)
mia = cal_mia(forgot_model.cuda(), unseen_dataloader_test)
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')

# %% [markdown]
# # Retrained Model

# %%
learning_rate = 0.01
log_step = 30

retrained_model = models.resnet18(pretrained=False)
num_features = retrained_model.fc.in_features
retrained_model.fc = nn.Linear(num_features, 2)
retrained_model = retrained_model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(retrained_model.parameters(), lr=learning_rate, momentum=0.9)

# %%
learning_rate = 0.01
best_test_acc = 0
best_epoch = 0

history = []
accuracy = []
num_original_epochs = 10
for epoch in range(num_original_epochs):
    train_loss, train_acc = train(retrained_model, retrain_dataloader_train)
    test_loss, test_acc = test(retrained_model, test_dataloader)
    history.append((train_loss, test_loss))
    accuracy.append((train_acc, test_acc))
# Out:
# [Epoch: 1 - Training]
# [Batch: 20] running train loss: 0.5961, running train accuracy: 0.7164
# [Batch: 40] running train loss: 0.6061, running train accuracy: 0.7242
# [Batch: 60] running train loss: 0.5889, running train accuracy: 0.7310
# [Batch: 80] running train loss: 0.5790, running train accuracy: 0.7385
# [Batch: 100] running train loss: 0.5731, running train accuracy: 0.7452
# [Batch: 120] running train loss: 0.5789, running train accuracy: 0.7431
# [Batch: 140] running train loss: 0.5786, running train accuracy: 0.7430
# [Batch: 160] running train loss: 0.5821, running train accuracy: 0.7417
# [Batch: 180] running train loss: 0.5784, running train accuracy: 0.7436
# [Batch: 200] running train loss: 0.5809, running train accuracy: 0.7455
# [Batch: 220] running train loss: 0.5735, running train accuracy: 0.7479
# [Batch: 240] running train loss: 0.5650, running train accuracy: 0.7509
# train loss: 0.5624, accuracy: 0.7518
# elapsed time: 456.42134046554565
# [Test]
# [Batch: 1] running test loss: 0.3595, running test accuracy: 0.8438
# [Batch: 20] running test loss: 0.4117, running test accuracy: 0.8297
# test loss: 0.4007, accuracy: 0.8373
# elapsed time: 48.46740007400513
# [Epoch: 2 - Training]
# [Batch: 20] running train loss: 0.4634, running train accuracy: 0.7930
# [Batch: 40] running train loss: 0.4689, running train accuracy: 0.7906
# [Batch: 60] running train loss: 0.4694, running train accuracy: 0.7898
# [Batch: 80] running train loss: 0.4609, running train accuracy: 0.7938
# [Batch: 100] running train loss: 0.4578, running train accuracy: 0.7969
# [Batch: 120] running train loss: 0.4625, running train accuracy: 0.7954
# [Batch: 140] running train loss: 0.4592, running train accuracy: 0.7982
# [Batch: 160] running train loss: 0.4584, running train accuracy: 0.7966
# [Batch: 180] running train loss: 0.4593, running train accuracy: 0.7946
# [Batch: 200] running train loss: 0.4652, running train accuracy: 0.7925
# [Batch: 220] running train loss: 0.4617, running train accuracy: 0.7954
# [Batch: 240] running train loss: 0.4601, running train accuracy: 0.7958
# train loss: 0.4580, accuracy: 0.7972
# elapsed time: 437.4302637577057
# [Test]
# [Batch: 1] running test loss: 0.3484, running test accuracy: 0.8438
# [Batch: 20] running test loss: 0.4511, running test accuracy: 0.8359
# test loss: 0.4286, accuracy: 0.8436
# elapsed time: 50.63192343711853
# [Epoch: 3 - Training]
# [Batch: 20] running train loss: 0.3985, running train accuracy: 0.8227
# [Batch: 40] running train loss: 0.3866, running train accuracy: 0.8293
# [Batch: 60] running train loss: 0.3993, running train accuracy: 0.8247
# [Batch: 80] running train loss: 0.4059, running train accuracy: 0.8232
# [Batch: 100] running train loss: 0.4086, running train accuracy: 0.8234
# [Batch: 120] running train loss: 0.4155, running train accuracy: 0.8199
# [Batch: 140] running train loss: 0.4237, running train accuracy: 0.8176
# [Batch: 160] running train loss: 0.4184, running train accuracy: 0.8184
# [Batch: 180] running train loss: 0.4176, running train accuracy: 0.8180
# [Batch: 200] running train loss: 0.4155, running train accuracy: 0.8191
# [Batch: 220] running train loss: 0.4111, running train accuracy: 0.8206
# [Batch: 240] running train loss: 0.4088, running train accuracy: 0.8215
# train loss: 0.4087, accuracy: 0.8216
# elapsed time: 383.4190683364868
# [Test]
# [Batch: 1] running test loss: 0.3268, running test accuracy: 0.8750
# [Batch: 20] running test loss: 0.4074, running test accuracy: 0.8516
# test loss: 0.3866, accuracy: 0.8586
# elapsed time: 46.10333275794983
# [Epoch: 4 - Training]
# [Batch: 20] running train loss: 0.4194, running train accuracy: 0.8219
# [Batch: 40] running train loss: 0.3873, running train accuracy: 0.8320
# [Batch: 60] running train loss: 0.3824, running train accuracy: 0.8354
# [Batch: 80] running train loss: 0.3793, running train accuracy: 0.8387
# [Batch: 100] running train loss: 0.3775, running train accuracy: 0.8389
# [Batch: 120] running train loss: 0.3793, running train accuracy: 0.8375
# [Batch: 140] running train loss: 0.3801, running train accuracy: 0.8368
# [Batch: 160] running train loss: 0.3786, running train accuracy: 0.8389
# [Batch: 180] running train loss: 0.3795, running train accuracy: 0.8382
# [Batch: 200] running train loss: 0.3799, running train accuracy: 0.8377
# [Batch: 220] running train loss: 0.3823, running train accuracy: 0.8376
# [Batch: 240] running train loss: 0.3808, running train accuracy: 0.8377
# train loss: 0.3803, accuracy: 0.8382
# elapsed time: 365.8831408023834
# [Test]
# [Batch: 1] running test loss: 0.3376, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.3748, running test accuracy: 0.8609
# test loss: 0.3630, accuracy: 0.8741
# elapsed time: 44.92646265029907
# [Epoch: 5 - Training]
# [Batch: 20] running train loss: 0.3917, running train accuracy: 0.8367
# [Batch: 40] running train loss: 0.4175, running train accuracy: 0.8332
# [Batch: 60] running train loss: 0.4173, running train accuracy: 0.8294
# [Batch: 80] running train loss: 0.4045, running train accuracy: 0.8311
# [Batch: 100] running train loss: 0.3964, running train accuracy: 0.8356
# [Batch: 120] running train loss: 0.3895, running train accuracy: 0.8372
# [Batch: 140] running train loss: 0.3815, running train accuracy: 0.8398
# [Batch: 160] running train loss: 0.3783, running train accuracy: 0.8415
# [Batch: 180] running train loss: 0.3759, running train accuracy: 0.8419
# [Batch: 200] running train loss: 0.3733, running train accuracy: 0.8428
# [Batch: 220] running train loss: 0.3744, running train accuracy: 0.8417
# [Batch: 240] running train loss: 0.3743, running train accuracy: 0.8433
# train loss: 0.3734, accuracy: 0.8436
# elapsed time: 365.56108117103577
# [Test]
# [Batch: 1] running test loss: 0.3420, running test accuracy: 0.8594
# [Batch: 20] running test loss: 0.5537, running test accuracy: 0.8516
# test loss: 0.5184, accuracy: 0.8557
# elapsed time: 44.71806812286377
# [Epoch: 6 - Training]
# [Batch: 20] running train loss: 0.3587, running train accuracy: 0.8484
# [Batch: 40] running train loss: 0.3502, running train accuracy: 0.8504
# [Batch: 60] running train loss: 0.3454, running train accuracy: 0.8508
# [Batch: 80] running train loss: 0.3413, running train accuracy: 0.8520
# [Batch: 100] running train loss: 0.3357, running train accuracy: 0.8531
# [Batch: 120] running train loss: 0.3381, running train accuracy: 0.8531
# [Batch: 140] running train loss: 0.3387, running train accuracy: 0.8538
# [Batch: 160] running train loss: 0.3391, running train accuracy: 0.8535
# [Batch: 180] running train loss: 0.3403, running train accuracy: 0.8532
# [Batch: 200] running train loss: 0.3409, running train accuracy: 0.8533
# [Batch: 220] running train loss: 0.3416, running train accuracy: 0.8529
# [Batch: 240] running train loss: 0.3442, running train accuracy: 0.8527
# train loss: 0.3443, accuracy: 0.8532
# elapsed time: 365.9392523765564
# [Test]
# [Batch: 1] running test loss: 0.2417, running test accuracy: 0.9062
# [Batch: 20] running test loss: 0.2939, running test accuracy: 0.8859
# test loss: 0.2790, accuracy: 0.8969
# elapsed time: 45.114957094192505
# [Epoch: 7 - Training]
# [Batch: 20] running train loss: 0.3513, running train accuracy: 0.8531
# [Batch: 40] running train loss: 0.3388, running train accuracy: 0.8535
# [Batch: 60] running train loss: 0.3386, running train accuracy: 0.8557
# [Batch: 80] running train loss: 0.3399, running train accuracy: 0.8561
# [Batch: 100] running train loss: 0.3405, running train accuracy: 0.8575
# [Batch: 120] running train loss: 0.3406, running train accuracy: 0.8566
# [Batch: 140] running train loss: 0.3338, running train accuracy: 0.8595
# [Batch: 160] running train loss: 0.3336, running train accuracy: 0.8587
# [Batch: 180] running train loss: 0.3342, running train accuracy: 0.8582
# [Batch: 200] running train loss: 0.3310, running train accuracy: 0.8599
# [Batch: 220] running train loss: 0.3309, running train accuracy: 0.8589
# [Batch: 240] running train loss: 0.3300, running train accuracy: 0.8600
# train loss: 0.3296, accuracy: 0.8602
# elapsed time: 364.2922077178955
# [Test]
# [Batch: 1] running test loss: 0.7085, running test accuracy: 0.5781
# [Batch: 20] running test loss: 0.6896, running test accuracy: 0.6039
# test loss: 0.6883, accuracy: 0.6015
# elapsed time: 45.13352370262146
# [Epoch: 8 - Training]
# [Batch: 20] running train loss: 0.2962, running train accuracy: 0.8898
# [Batch: 40] running train loss: 0.3031, running train accuracy: 0.8785
# [Batch: 60] running train loss: 0.3203, running train accuracy: 0.8690
# [Batch: 80] running train loss: 0.3254, running train accuracy: 0.8623
# [Batch: 100] running train loss: 0.3222, running train accuracy: 0.8656
# [Batch: 120] running train loss: 0.3243, running train accuracy: 0.8659
# [Batch: 140] running train loss: 0.3239, running train accuracy: 0.8646
# [Batch: 160] running train loss: 0.3232, running train accuracy: 0.8643
# [Batch: 180] running train loss: 0.3230, running train accuracy: 0.8642
# [Batch: 200] running train loss: 0.3249, running train accuracy: 0.8633
# [Batch: 220] running train loss: 0.3202, running train accuracy: 0.8660
# [Batch: 240] running train loss: 0.3214, running train accuracy: 0.8661
# train loss: 0.3208, accuracy: 0.8665
# elapsed time: 363.2475411891937
# [Test]
# [Batch: 1] running test loss: 0.2592, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.3003, running test accuracy: 0.8875
# test loss: 0.2818, accuracy: 0.8959
# elapsed time: 44.06249785423279
# [Epoch: 9 - Training]
# [Batch: 20] running train loss: 0.3468, running train accuracy: 0.8508
# [Batch: 40] running train loss: 0.3226, running train accuracy: 0.8652
# [Batch: 60] running train loss: 0.3213, running train accuracy: 0.8685
# [Batch: 80] running train loss: 0.3195, running train accuracy: 0.8682
# [Batch: 100] running train loss: 0.3190, running train accuracy: 0.8670
# [Batch: 120] running train loss: 0.3232, running train accuracy: 0.8645
# [Batch: 140] running train loss: 0.3229, running train accuracy: 0.8638
# [Batch: 160] running train loss: 0.3181, running train accuracy: 0.8657
# [Batch: 180] running train loss: 0.3158, running train accuracy: 0.8673
# [Batch: 200] running train loss: 0.3153, running train accuracy: 0.8677
# [Batch: 220] running train loss: 0.3141, running train accuracy: 0.8678
# [Batch: 240] running train loss: 0.3150, running train accuracy: 0.8682
# train loss: 0.3152, accuracy: 0.8679
# elapsed time: 364.27093052864075
# [Test]
# [Batch: 1] running test loss: 0.2183, running test accuracy: 0.9219
# [Batch: 20] running test loss: 0.3017, running test accuracy: 0.8836
# test loss: 0.2820, accuracy: 0.8930
# elapsed time: 44.75726342201233
# [Epoch: 10 - Training]
# [Batch: 20] running train loss: 0.2781, running train accuracy: 0.8781
# [Batch: 40] running train loss: 0.3006, running train accuracy: 0.8758
# [Batch: 60] running train loss: 0.3153, running train accuracy: 0.8693
# [Batch: 80] running train loss: 0.3121, running train accuracy: 0.8693
# [Batch: 100] running train loss: 0.3072, running train accuracy: 0.8725
# [Batch: 120] running train loss: 0.3096, running train accuracy: 0.8710
# [Batch: 140] running train loss: 0.3059, running train accuracy: 0.8715
# [Batch: 160] running train loss: 0.3052, running train accuracy: 0.8725
# [Batch: 180] running train loss: 0.3030, running train accuracy: 0.8728
# [Batch: 200] running train loss: 0.3039, running train accuracy: 0.8722
# [Batch: 220] running train loss: 0.3046, running train accuracy: 0.8709
# [Batch: 240] running train loss: 0.3047, running train accuracy: 0.8701
# train loss: 0.3043, accuracy: 0.8703
# elapsed time: 373.14069509506226
# [Test]
# [Batch: 1] running test loss: 0.2388, running test accuracy: 0.9375
# [Batch: 20] running test loss: 0.2779, running test accuracy: 0.9047
# test loss: 0.2688, accuracy: 0.9046
# elapsed time: 45.1906418800354

# %%
import matplotlib.pyplot as plt

train_losses, test_losses = zip(*history)
train_accuracies, test_accuracies = zip(*accuracy)

plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Train Loss')
plt.plot(range(1, len(test_losses) + 1), test_losses, label='Test Loss')
plt.title('Training and Testing Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, len(test_accuracies) + 1), test_accuracies, label='Test Accuracy')
plt.title('Training and Testing Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
test_acc = evaluation(retrained_model, test_dataloader)
unseen_acc = evaluation(retrained_model, unseen_dataloader_test)
mia = cal_mia(retrained_model.cuda(), unseen_dataloader_test)
print()
print(f'Test Acc: {test_acc}')
print(f'Unseen Acc: {unseen_acc}')
print(f'MIA: {mia}')
print(f'Final Score: {(test_acc["Acc"] + (1 - abs(mia["MIA"] - 0.5) * 2)) / 2}')
# Out:
# Test Acc: {'Loss': 0.269, 'Acc': 0.9046004842615012}
# Unseen Acc: {'Loss': 0.337, 'Acc': 0.8877805486284289}
# MIA: {'MIA': 0.46419753086419757, 'Forgeting Score': 0.03580246913580243}
# Final Score: 0.9164977729949482
